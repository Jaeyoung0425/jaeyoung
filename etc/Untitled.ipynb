# %%
import pandas as pd
ex_df=pd.read_excel(r'/Users/JalynneHEO/OneDrive - 주식회사 투디지트/바탕 화면/Jalynne_excercise3.xlsx', engine = 'openpyxl')
print(ex_df)
# Out:
#        Unnamed: 0                                                _id  \
# 0               0                                              연세대학교
# 1               1                                                송하진
# 2               2                                                민주당
# 3               3                                                전병헌
# 4               4                                      연안 이씨 (延安 李氏)
# ...           ...                                                ...
# 49995       49995  환경실천연합회International Environment Action Associ...
# 49996       49996                                        괴산 열차 전복 사고
# 49997       49997                                             광저우 푸리
# 49998       49998               남서울경전철 주식회사South Seoul LRT Co., Ltd.
# 49999       49999                                                 킬잇
#
#                                     건학이념                 교색  \
# 0      진리가 너희를 자유케 하리라, (요한복음 8:32)[주 1]  로얄 블루(Royal blue)
# ...

# %%
# i=정당 중에 값이 있는 행만 가져온 dataframe (3418x1590)
i=ex_df.dropna(subset=['정당'])
print(i)
# Out:
#        Unnamed: 0                             _id 건학이념   교색 교직원 수   국가   규모  \
# 1               1                             송하진  NaN  NaN   NaN  NaN  NaN
# 3               3                             전병헌  NaN  NaN   NaN  NaN  NaN
# 6               6                             신경민  NaN  NaN   NaN  NaN  NaN
# 7               7                             김준성  NaN  NaN   NaN  NaN  NaN
# 9               9                             정홍원  NaN  NaN   NaN  NaN  NaN
# ...           ...                             ...  ...  ...   ...  ...  ...
# 49819       49819             털시 개버드Tulsi Gabbard  NaN  NaN   NaN  NaN  NaN
# 49864       49864  종만학(鍾萬學)Basuki Tjahaja Purnama  NaN  NaN   NaN  NaN  NaN
# 49879       49879       발데마르 파블라크 Waldemar Pawlak  NaN  NaN   NaN  NaN  NaN
# 49979       49979                             이홍기  NaN  NaN   NaN  NaN  NaN
# 49982       49982                             박영희  NaN  NaN   NaN  NaN  NaN
#
# ...

# %%
print(i['출생일'])

# %%
column_birth=i['출생일'].astype(str).str[:4]
print(column_birth)
# Out:
# 1        1952
# 3         nan
# 6         nan
# 7        1952
# 9        1944
#          ...
# 49819    1981
# 49864    1966
# 49879     nan
# 49979    1958
# 49982     nan
# Name: 출생일, Length: 3418, dtype: object

# %%
print(type(column_birth))
# Out:
# <class 'pandas.core.series.Series'>

# %%
birth_list=list(column_birth)
print(birth_list)
# Out:
# ['1952', 'nan', 'nan', '1952', '1944', '1873', '1955', '1955', '1955', '1987', '1957', 'nan', '1965', '1955', '1953', '1961', '1946', '1950', '1606', '1936', '1897', '1574', 'nan', 'nan', '1875', '1868', 'nan', 'nan', '1899', '1959', 'nan', 'nan', '1548', '1614', '1959', 'nan', '1957', '1958', '1942', 'nan', 'nan', '1927', '1950', '1920', 'nan', '1956', 'nan', 'nan', '1924', '1955', 'nan', '1917', '1610', '1968', '1944', '1953', '1637', 'nan', '1932', '1949', 'nan', '1891', '1949', '1953', '1948', '1951', 'nan', '1970', 'nan', 'nan', 'nan', '1900', 'nan', '1941', 'nan', 'nan', '1619', 'nan', 'nan', 'nan', '1955', 'nan', '1955', '1974', 'nan', '1960', 'nan', 'nan', '1947', '1952', '1888', 'nan', 'nan', 'nan', '1948', 'nan', '1962', '1961', 'nan', '1947', '1953', '1919', '1938', '1567', 'nan', 'nan', '1948', 'nan', 'nan', 'nan', '1940', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', '1953', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', '1960', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', '1842', '
# ...

# %%
import re

# %%
print(bool(re.match('\d\d\d\d','1234')))
# Out:
# True

# %%
birth_list = list(birth_list)

# %%
birth=[]


for n in birth_list:
    if bool(re.match('\d\d\d\d',n))==True:
        birth.append(n)
    else:
        pass
    
print(birth)
# Out:
# ['1952', '1952', '1944', '1873', '1955', '1955', '1955', '1987', '1957', '1965', '1955', '1953', '1961', '1946', '1950', '1606', '1936', '1897', '1574', '1875', '1868', '1899', '1959', '1548', '1614', '1959', '1957', '1958', '1942', '1927', '1950', '1920', '1956', '1924', '1955', '1917', '1610', '1968', '1944', '1953', '1637', '1932', '1949', '1891', '1949', '1953', '1948', '1951', '1970', '1900', '1941', '1619', '1955', '1955', '1974', '1960', '1947', '1952', '1888', '1948', '1962', '1961', '1947', '1953', '1919', '1938', '1567', '1948', '1940', '1953', '1960', '1842', '1383', '1330', '1405', '1586', '1948', '1950', '1441', '1595', '1765', '1861', '1354', '1315', '1984', '1328', '1963', '1402', '1546', '1347', '1499', '1348', '1596', '1537', '1728', '1533', '1396', '1348', '1436', '1610', '1766', '1537', '1561', '1563', '1397', '1944', '1856', '1539', '1544', '1347', '1958', '1418', '1422', '1580', '1980', '1552', '1860', '1730', '1493', '1375', '1824', '1598', '1342', '1556', '1546
# ...

# %%
#birth안에 있는 원소를 숫자로 바꾸기

birth=[int (i) for i in birth]

# %%
birth_int=[]

for x in birth:
    if x>=1930:
        birth_int.append(x)
    else:
        pass
print(birth_int)
# Out:
# [1952, 1952, 1944, 1955, 1955, 1955, 1987, 1957, 1965, 1955, 1953, 1961, 1946, 1950, 1936, 1959, 1959, 1957, 1958, 1942, 1950, 1956, 1955, 1968, 1944, 1953, 1932, 1949, 1949, 1953, 1948, 1951, 1970, 1941, 1955, 1955, 1974, 1960, 1947, 1952, 1948, 1962, 1961, 1947, 1953, 1938, 1948, 1940, 1953, 1960, 1948, 1950, 1984, 1963, 1944, 1958, 1980, 1931, 1990, 1951, 1969, 1943, 1939, 1961, 1952, 1955, 1931, 1964, 1959, 1964, 1949, 1946, 1942, 1965, 1958, 1946, 1980, 1955, 1955, 1930, 1956, 1995, 1936, 1938, 1964, 1947, 1967, 1938, 1940, 1956, 1971, 1946, 1972, 1964, 1950, 1983, 1977, 1953, 1945, 1965, 1941, 1943, 1955, 1937, 1931, 1949, 1962, 1956, 1957, 1972, 1932, 1963, 1956, 1964, 1973, 1942, 1954, 1954, 1974, 1965, 1947, 1946, 1963, 1948, 1959, 1954, 1973, 1942, 1960, 1953, 1936, 1963, 1952, 1950, 1967, 1960, 1936, 1964, 1938, 1951, 1953, 1940, 1961, 1946, 1970, 1951, 1934, 1953, 1967, 1958, 1945, 1953, 1954, 1950, 1934, 1952, 1957, 1970, 1944, 1981, 1945, 1954, 1950, 1931, 1966, 1941, 1
# ...

# %%
column_birth= column_birth[column_birth.str.isdecimal()]

# %%
column_birth=column_birth.astype(int)

# %%
column_birth=column_birth[column_birth>=1930]

# %%
index_list=column_birth.index.tolist()

# %%
print(ex_df.loc[index_list,:])
# Out:
#        Unnamed: 0                                _id 건학이념   교색 교직원 수   국가  \
# 1               1                                송하진  NaN  NaN   NaN  NaN
# 7               7                                김준성  NaN  NaN   NaN  NaN
# 9               9                                정홍원  NaN  NaN   NaN  NaN
# 14             14                                강인규  NaN  NaN   NaN  NaN
# 15             15                                강임준  NaN  NaN   NaN  NaN
# ...           ...                                ...  ...  ...   ...  ...
# 49514       49514  크리스탈리나 게오르기에바Кристалина Георгиева  NaN  NaN   NaN  NaN
# 49662       49662     조아킴 용비오팡고Joachim Yhombi-Opango  NaN  NaN   NaN  NaN
# 49819       49819                털시 개버드Tulsi Gabbard  NaN  NaN   NaN  NaN
# 49864       49864     종만학(鍾萬學)Basuki Tjahaja Purnama  NaN  NaN   NaN  NaN
# 49979       49979                                이홍기  NaN  NaN   NaN  NaN
#
#         규모 대학원생 수  부총장  상징물  ...   시진 시선속도 적경 고유운동 적위 고유운동 뷰파인더 배율 변광성 분류  \
# ...

# %%
#nanall_0=nanall dataframe에서 열의 모든 값이 nan인 열을 제외한 것 (1228x312)

nanall=ex_df.loc[index_list,:]
nanall_0=nanall.dropna(axis = 1, how = 'all')
print(nanall_0)
# Out:
#        Unnamed: 0                                _id   국가   설립  \
# 1               1                                송하진  NaN  NaN
# 7               7                                김준성  NaN  NaN
# 9               9                                정홍원  NaN  NaN
# 14             14                                강인규  NaN  NaN
# 15             15                                강임준  NaN  NaN
# ...           ...                                ...  ...  ...
# 49514       49514  크리스탈리나 게오르기에바Кристалина Георгиева  NaN  NaN
# 49662       49662     조아킴 용비오팡고Joachim Yhombi-Opango  NaN  NaN
# 49819       49819                털시 개버드Tulsi Gabbard  NaN  NaN
# 49864       49864     종만학(鍾萬學)Basuki Tjahaja Purnama  NaN  NaN
# 49979       49979                                이홍기  NaN  NaN
#
#                          웹사이트   종교   종류   표어   감독   리그  ...   형량 2013 에이전시  \
# 1                     송하진 트위터  개신교  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# ...

# %%
#nanall_1=nanall_0에서 채워진 셀이 150개 이생인 열을 골라낸 것 (1228x20)

nanall_1=nanall_0.dropna(axis=1, thresh=150)
print(nanall_1)
# Out:
#        Unnamed: 0                                _id                    웹사이트  \
# 1               1                                송하진                 송하진 트위터
# 7               7                                김준성                     NaN
# 9               9                                정홍원                     NaN
# 14             14                                강인규                     NaN
# 15             15                                강임준                     NaN
# ...           ...                                ...                     ...
# 49514       49514  크리스탈리나 게오르기에바Кристалина Георгиева                     NaN
# 49662       49662     조아킴 용비오팡고Joachim Yhombi-Opango                     NaN
# 49819       49819                털시 개버드Tulsi Gabbard       gabbard.house.gov
# 49864       49864     종만학(鍾萬學)Basuki Tjahaja Purnama                     NaN
# 49979       49979                                이홍기  이홍기 - 인스타그램, 이홍기 - 트위터
#
# ...

# %%
print(nanall_1.replace({'정당':{" ",""}}))
# Out:
#        Unnamed: 0                                _id                    웹사이트  \
# 1               1                                송하진                 송하진 트위터
# 7               7                                김준성                     NaN
# 9               9                                정홍원                     NaN
# 14             14                                강인규                     NaN
# 15             15                                강임준                     NaN
# ...           ...                                ...                     ...
# 49514       49514  크리스탈리나 게오르기에바Кристалина Георгиева                     NaN
# 49662       49662     조아킴 용비오팡고Joachim Yhombi-Opango                     NaN
# 49819       49819                털시 개버드Tulsi Gabbard       gabbard.house.gov
# 49864       49864     종만학(鍾萬學)Basuki Tjahaja Purnama                     NaN
# 49979       49979                                이홍기  이홍기 - 인스타그램, 이홍기 - 트위터
#
# ...

# %%
a=nanall_1.replace({'정당':{" ",""}})

# %%
print(a['국적'].str.contains('대한민국'))
# Out:
# 1        True
# 7        True
# 9        True
# 14        NaN
# 15       True
#          ...
# 49514     NaN
# 49662     NaN
# 49819     NaN
# 49864     NaN
# 49979     NaN
# Name: 국적, Length: 1228, dtype: object

# %%
#국적이 빈 셀인 행을 제외한 것 (621x20)

a=a.dropna(subset=['국적'])
print(a)
# Out:
#        Unnamed: 0  _id         웹사이트              종교  \
# 1               1  송하진      송하진 트위터             개신교
# 7               7  김준성          NaN             개신교
# 9               9  정홍원          NaN             기독교
# 15             15  강임준          NaN             NaN
# 31             31  NaN      Tatu.ru             NaN
# ...           ...  ...          ...             ...
# 48278       48278  박노욱      박노욱 블로그             무종교
# 48483       48483   이훈          NaN             NaN
# 49019       49019  이동우  이동우 네이버 블로그  천주교 (세례명: 마르코)
# 49270       49270  김진규          NaN             NaN
# 49465       49465  박삼기        보트 비전             NaN
#
#                                                       경력    국적      배우자  \
# 1                                                   전주시장  대한민국      오경진
# 7                                                    NaN  대한민국      NaN
# 9      제27대 법무연수원장, 광주지방검찰청 검사장, 부산지방검찰청 검사장, 제9대 대한법...  대한민국  최옥자(재혼)
# ...

# %%
#국적이 있는 것 중에서 '대한민국'인 것만 골라내야함

print(a['국적'].str.contains('대한민국'))
# Out:
# 1         True
# 7         True
# 9         True
# 15        True
# 31        True
#          ...
# 48278    False
# 48483     True
# 49019     True
# 49270     True
# 49465     True
# Name: 국적, Length: 621, dtype: bool

# %%
#a는 국적이 비어있는 셀을 제외한 데이터프레임

index_list5=list(a.index)
result_list=[]

for temp_index in index_list5:
    temp_data=a.loc[temp_index,:]
    print(temp_data['국적'])
    
    if temp_data['국적']=='대한민국':
        result_list.append(temp_index)
    else:
        pass
print(result_list)
# Out:
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 중화인민공화국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 조선민주주의인민공화국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 뉴질랜드
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 영국
# 대한민국
# 미국
# 미국
# 대한민국
# 미국
# 대한민국
# 베네수엘라
# 프랑스
# 대한민국
# 대한민국
# 미얀마
# 브라질
# 대한민국
# 중화민국
# 몽골
# 대한민국
# 이탈리아
# 미국
# 태국
# 대한민국
# 시리아
# 대한민국
# 베트남
# 룩셈부르크
# 네덜란드
# 미국
# 미국
# 인도
# 대한민국
# 루마니아
# 영국
# 대한민국
# 대한민국
# 대한민국
# 영국
# 이탈리아
# 대한민국
# 영국
# 영국
# 대한민국
# 리히텐슈타인
# 대한민국
# 인도네시아
# 영국
# 라이베리아
# 대한민국
# 이란
# 대한민국
# 대한민국
# 대한민국
# 중화민국
# 대한민국
# 오스트리아
# 대한민국
# 방글라데시
# 이란
# 대한민국
# 케냐
# 말라위
# 대한민국
# 대한민국
# 레바논
# 몽골
# 대한민국
# 일본
# 대한민국
# 미국
# 미국
# 독일
# 이집트
# 차드
# 러시아
# 러시아
# 에스토니아
# 대한민국
# 대한민국
# 대한민국
# 미국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 대한민국
# 아르메니아
# ...

# %%
#국적이 '대한민국'인 행만 가져온 a(a=dataframe) (410x20)

print(a.loc[result_list,:])
# Out:
#        Unnamed: 0  _id             웹사이트              종교  \
# 1               1  송하진          송하진 트위터             개신교
# 7               7  김준성              NaN             개신교
# 9               9  정홍원              NaN             기독교
# 15             15  강임준              NaN             NaN
# 31             31  NaN          Tatu.ru             NaN
# ...           ...  ...              ...             ...
# 48071       48071  이승훈  스타빌리지엔터테인먼트 이승훈             무종교
# 48483       48483   이훈              NaN             NaN
# 49019       49019  이동우      이동우 네이버 블로그  천주교 (세례명: 마르코)
# 49270       49270  김진규              NaN             NaN
# 49465       49465  박삼기            보트 비전             NaN
#
#                                                       경력    국적      배우자  \
# 1                                                   전주시장  대한민국      오경진
# 7                                                    NaN  대한민국      NaN
# 9      제27대 법무연수원장, 광주지방검찰청 검사장, 부산지방검찰청 검사장, 제9대 대한법...  대한민국  최옥자(재혼)
# ...

# %%
#국적이 '대한민국'인 데이터프레임 중 '출생일' 열만 가져옴
b=a.loc[result_list,:]
print(b['출생일'])

index_list_korea=list(b.index)
print(index_list_korea)
# Out:
# 1         1952년 4월 29일(1952-04-29) (68세)
# 7          1952년 5월 5일(1952-05-05) (68세)
# 9         1944년 10월 9일(1944-10-09) (76세)
# 15        1955년 9월 20일(1955-09-20) (65세)
# 31       1987년 07월 14일(1987-07-14) (33세)
#                       ...
# 48071     1955년 1월 10일(1955-01-10) (65세)
# 48483     1986년 4월 29일(1986-04-29) (34세)
# 49019    1954년 11월 16일(1954-11-16) (66세)
# 49270     1997년 2월 24일(1997-02-24) (23세)
# 49465     1952년 6월 18일(1952-06-18) (68세)
# Name: 출생일, Length: 410, dtype: object
# ...

# %%
print(b.count())
# Out:
# Unnamed: 0    410
# _id           409
# 웹사이트          146
# 종교            197
# 경력            272
# 국적            410
# 배우자           178
# 본관            195
# 임기            357
# 자녀            176
# 전임            230
# 정당            410
# 출생일           410
# 출생지           381
# 학력            364
# 거주지            94
# 대통령           229
# 총리            181
# 사망일            37
# 후임            115
# dtype: int64

# %%
#b 

bb=b.count()
bb.sort_values(ascending=False)
# Out:
# Unnamed: 0    410
# 출생일           410
# 정당            410
# 국적            410
# _id           409
# 출생지           381
# 학력            364
# 임기            357
# 경력            272
# 전임            230
# 대통령           229
# 종교            197
# 본관            195
# 총리            181
# 배우자           178
# 자녀            176
# 웹사이트          146
# 후임            115
# 거주지            94
# 사망일            37
# dtype: int64

# %%
#출생일을 '(' ')'로 슬라이싱하기


index_list=list(b.index)
result_list1=[]

for temp_index in index_list:
    temp_data=b.loc[temp_index,:]
    
    point=temp_data['출생일'].find('(')
    point1=temp_data['출생일'].find(')')
    target = temp_data['출생일'][point+1:point1].strip().replace(' ','')
    print(target)
    print(bool(re.match('.*-.*-.*',target)))
    if bool(re.match('.*-.*-.*',temp_data['출생일'][point+1:point1].strip()))== True:
        temp_data['출생일'][point+1:point1].replace('-','')
        result_list1.append(temp_data['출생일'][point+1:point1].replace('-',''))
    else:
        result_list1.append('no result')
        pass

#a['column'] = result_list1  → 그러기 위해서는 행의 갯수가 똑같아야 함
# Out:
# 1952-04-29
# True
# 1952-05-05
# True
# 1944-10-09
# True
# 1955-09-20
# True
# 1987-07-14
# True
# 1957-05-14
# True
# 1965-01-03
# True
# 1955-11-29
# True
# 1953-01-24
# True
# 1961-02-07
# True
# 1946-09-01
# True
# 1950-07-16
# True
# 1936-12-28
# True
# 1959-03-21
# True
# 1958-11-08
# True
# 1950-11-05
# True
# 1956-12-24
# True
# 1955-02-17
# True
# 52–53세
# False
# 1944-04-16
# True
# 1953-08-03
# True
# 1949-06-18
# True
# 1949-05-23
# True
# 1951-09-11
# True
# 1941-12-19
# True
# 1955-11-10
# True
# 1974-11-03
# True
# 1960-12-07
# True
# 1947-03-21
# True
# 1952-02-02
# True
# 1948-09-11
# True
# 1962-10-15
# True
# 1961-04-23
# True
# 1947-01-09
# True
# 1938-12-02
# True
# 1940-07-11
# True
# 1953-09-09
# True
# 1948-12-11
# True
# 1984-01-08
# True
# 1963-12-08
# True
# 1958-03-25
# True
# 1980-01-01
# True
# 1990-11-15
# True
# 1951-04-07
# True
# 1969-03-13
# True
# 1939-03-10
# True
# 1961-03-15
# True
# 1955-05-17
# True
# 1964-08-25
# True
# 1964-02-08
# True
# ...

# %%
print(result_list1)
# Out:
# ['19520429', '19520505', '19441009', '19550920', '19870714', '19570514', '19650103', '19551129', '19530124', '19610207', '19460901', '19500716', '19361228', '19590321', '19581108', '19501105', '19561224', '19550217', 'no result', '19440416', '19530803', '19490618', '19490523', '19510911', '19411219', '19551110', '19741103', '19601207', '19470321', '19520202', '19480911', '19621015', '19610423', '19470109', '19381202', '19400711', '19530909', '19481211', '19840108', '19631208', '19580325', '19800101', '19901115', '19510407', '19690313', '19390310', '19610315', '19550517', '19640825', '19640208', '19491030', '19581120', '19460901', '19550815', '19300228', '19561108', '19950502', '19360208', '19380102', '19470418', '19560204', '19640625', '19530213', '19650120', '19621129', '19560628', '19740729', '19630627', '19541027', '19810325', '19450808', '19500106', '19630818', '19561201', '19551206', '19591023', '19671201', '19550517', '19600725', '19420605', '19360429', '19600203', '19460414', 
# ...

# %%
import re

# %%
print(bool(re.match('\d\d\d\d\d\d\d\d','12345678')))
# Out:
# True

# %%
#yyyymmdd형태로 만들긴 했는데 또 list로 만들어버림...

birth_8digits=[]

for n in result_list1:
    if bool(re.match('\d\d\d\d\d\d\d\d',n))==True:
        birth_8digits.append(n)
    else:
        
        pass
    
print(birth_8digits)
# Out:
# ['19520429', '19520505', '19441009', '19550920', '19870714', '19570514', '19650103', '19551129', '19530124', '19610207', '19460901', '19500716', '19361228', '19590321', '19581108', '19501105', '19561224', '19550217', '19440416', '19530803', '19490618', '19490523', '19510911', '19411219', '19551110', '19741103', '19601207', '19470321', '19520202', '19480911', '19621015', '19610423', '19470109', '19381202', '19400711', '19530909', '19481211', '19840108', '19631208', '19580325', '19800101', '19901115', '19510407', '19690313', '19390310', '19610315', '19550517', '19640825', '19640208', '19491030', '19581120', '19460901', '19550815', '19300228', '19561108', '19950502', '19360208', '19380102', '19470418', '19560204', '19640625', '19530213', '19650120', '19621129', '19560628', '19740729', '19630627', '19541027', '19810325', '19450808', '19500106', '19630818', '19561201', '19551206', '19591023', '19671201', '19550517', '19600725', '19420605', '19360429', '19600203', '19460414', '19890922', '
# ...

# %%
b['출생일']=result_list1

# %%
#출생일 #### ## ## 형태로 나온 데이터프레임=b
print(b)
# Out:
#        Unnamed: 0  _id             웹사이트              종교  \
# 1               1  송하진          송하진 트위터             개신교
# 7               7  김준성              NaN             개신교
# 9               9  정홍원              NaN             기독교
# 15             15  강임준              NaN             NaN
# 31             31  NaN          Tatu.ru             NaN
# ...           ...  ...              ...             ...
# 48071       48071  이승훈  스타빌리지엔터테인먼트 이승훈             무종교
# 48483       48483   이훈              NaN             NaN
# 49019       49019  이동우      이동우 네이버 블로그  천주교 (세례명: 마르코)
# 49270       49270  김진규              NaN             NaN
# 49465       49465  박삼기            보트 비전             NaN
#
#                                                       경력    국적      배우자  \
# 1                                                   전주시장  대한민국      오경진
# 7                                                    NaN  대한민국      NaN
# 9      제27대 법무연수원장, 광주지방검찰청 검사장, 부산지방검찰청 검사장, 제9대 대한법...  대한민국  최옥자(재혼)
# ...

# %%
#이름 예쁘게 정리하기

index_list2=list(b.index)

for temp_index_2 in index_list:
    temp_data_2=b.loc[temp_index_2,:]
    print(temp_data_2['_id'])
# Out:
# 송하진
# 김준성
# 정홍원
# 강임준
# nan
# 황교안
# 서정협
# 최형식
# 문재인
# 전동평
# 노무현盧武鉉
# 이완구
# 한승수
# 양승조
# 문인
# 정세균
# 유기상
# 김영록
# 김영수
# 한명숙
# 윤병세尹炳世
# 한덕수
# 윤장현
# 이용섭
# 이명박
# 조태열趙兌烈
# 김종민
# 이환주
# 정운찬
# 박근혜
# 김황식
# 유근기
# 김선수
# 김하중
# 김용준金容俊
# 김종인
# 박홍률朴洪律
# 이인제李仁濟
# 김정은
# 이재명
# 정헌율
# 이광재
# 김성주
# 유천호
# 김승수
# 이수성李壽成
# 권익현
# 문석진
# 박성수
# 진희선
# 노박래
# 박양우
# 고무통告誣桶
# 이철우
# 노신영
# 조희연
# 이상민
# 노재봉盧在鳳
# 고건
# 이시종
# 최문순
# 이재수
# 권영세
# 남경필
# 김현미
# 서승환
# 임병택
# 박준희
# 노경수盧慶秀
# 박용호
# 이건영李建榮
# 류우익
# 신계용申桂容
# 임태희任太熙
# 이춘희
# 한왕기
# 김경수金慶洙
# 성장현
# 염태영
# 박지원
# 이종찬
# 윤석열尹錫悅
# 정의용
# 김태호
# 황인홍
# 이성호
# 이재정李在禎
# 이정훈
# 정순균
# 이재용
# 변성완
# 권영진
# 정찬민
# 서철모
# 이상돈
# 박상천
# 김수영
# 조길형
# 강운태姜雲太
# 남궁영南宮英
# 박준영
# 노현송
# 안희정安熙正
# 허석
# 명현관
# 백두현
# 박재규
# 류순현柳淳鉉
# 이달곤
# 이강덕
# 허태정
# 정용래
# 정동영
# 이홍구李洪九
# 한경호韓徑浩
# 유승민
# 구충곤
# 이성문
# 이위준
# 이재갑
# 서병수
# 유한식
# 최형욱
# 이소영
# 김철우
# 이상희
# 정종순
# 민유숙
# 김수남
# 김동연金東兗
# 박준홍朴埈弘
# 김동철
# 김상돈
# 이병환
# 황선봉
# 김정섭
# 손지열孫智烈
# 김정호
# 오세훈
# 한범덕
# 김종량
# 이인영
# 최광수崔侊洙
# 고영주高永宙
# 김종식
# 원세훈
# 박종우
# 허성관許成寬
# 김석환
# 이의근李義根
# 유인촌柳仁村
# 심민
# ...

# %%
import re

# %%
index_list2=list(b.index)
result_list2=[]

for temp_index2 in index_list2:
    temp_data2=b.loc[temp_index2,:].copy()
    print(temp_data2['_id'])
    
    temp_data2['_id']=str( temp_data2['_id'])
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+')
    h=hangul.sub('',temp_data2['_id'])
    result_list2.append(h)
# Out:
# 송하진
# 김준성
# 정홍원
# 강임준
# nan
# 황교안
# 서정협
# 최형식
# 문재인
# 전동평
# 노무현盧武鉉
# 이완구
# 한승수
# 양승조
# 문인
# 정세균
# 유기상
# 김영록
# 김영수
# 한명숙
# 윤병세尹炳世
# 한덕수
# 윤장현
# 이용섭
# 이명박
# 조태열趙兌烈
# 김종민
# 이환주
# 정운찬
# 박근혜
# 김황식
# 유근기
# 김선수
# 김하중
# 김용준金容俊
# 김종인
# 박홍률朴洪律
# 이인제李仁濟
# 김정은
# 이재명
# 정헌율
# 이광재
# 김성주
# 유천호
# 김승수
# 이수성李壽成
# 권익현
# 문석진
# 박성수
# 진희선
# 노박래
# 박양우
# 고무통告誣桶
# 이철우
# 노신영
# 조희연
# 이상민
# 노재봉盧在鳳
# 고건
# 이시종
# 최문순
# 이재수
# 권영세
# 남경필
# 김현미
# 서승환
# 임병택
# 박준희
# 노경수盧慶秀
# 박용호
# 이건영李建榮
# 류우익
# 신계용申桂容
# 임태희任太熙
# 이춘희
# 한왕기
# 김경수金慶洙
# 성장현
# 염태영
# 박지원
# 이종찬
# 윤석열尹錫悅
# 정의용
# 김태호
# 황인홍
# 이성호
# 이재정李在禎
# 이정훈
# 정순균
# 이재용
# 변성완
# 권영진
# 정찬민
# 서철모
# 이상돈
# 박상천
# 김수영
# 조길형
# 강운태姜雲太
# 남궁영南宮英
# 박준영
# 노현송
# 안희정安熙正
# 허석
# 명현관
# 백두현
# 박재규
# 류순현柳淳鉉
# 이달곤
# 이강덕
# 허태정
# 정용래
# 정동영
# 이홍구李洪九
# 한경호韓徑浩
# 유승민
# 구충곤
# 이성문
# 이위준
# 이재갑
# 서병수
# 유한식
# 최형욱
# 이소영
# 김철우
# 이상희
# 정종순
# 민유숙
# 김수남
# 김동연金東兗
# 박준홍朴埈弘
# 김동철
# 김상돈
# 이병환
# 황선봉
# 김정섭
# 손지열孫智烈
# 김정호
# 오세훈
# 한범덕
# 김종량
# 이인영
# 최광수崔侊洙
# 고영주高永宙
# 김종식
# 원세훈
# 박종우
# 허성관許成寬
# 김석환
# 이의근李義根
# 유인촌柳仁村
# 심민
# ...

# %%
#이름 한자 제외하고 뽑아내기

print(result_list2)
# Out:
# ['송하진', '김준성', '정홍원', '강임준', '', '황교안', '서정협', '최형식', '문재인', '전동평', '노무현', '이완구', '한승수', '양승조', '문인', '정세균', '유기상', '김영록', '김영수', '한명숙', '윤병세', '한덕수', '윤장현', '이용섭', '이명박', '조태열', '김종민', '이환주', '정운찬', '박근혜', '김황식', '유근기', '김선수', '김하중', '김용준', '김종인', '박홍률', '이인제', '김정은', '이재명', '정헌율', '이광재', '김성주', '유천호', '김승수', '이수성', '권익현', '문석진', '박성수', '진희선', '노박래', '박양우', '고무통', '이철우', '노신영', '조희연', '이상민', '노재봉', '고건', '이시종', '최문순', '이재수', '권영세', '남경필', '김현미', '서승환', '임병택', '박준희', '노경수', '박용호', '이건영', '류우익', '신계용', '임태희', '이춘희', '한왕기', '김경수', '성장현', '염태영', '박지원', '이종찬', '윤석열', '정의용', '김태호', '황인홍', '이성호', '이재정', '이정훈', '정순균', '이재용', '변성완', '권영진', '정찬민', '서철모', '이상돈', '박상천', '김수영', '조길형', '강운태', '남궁영', '박준영', '노현송', '안희정', '허석', '명현관', '백두현', '박재규', '류순현', '이달곤', '이강덕', '허태정', '정용래', '정동영', '이홍구', '한경호', '유승민', '구충곤', '이성문', '이위준', '이재갑', '서병수', '유한식', '최형욱', '이소영', '김철우', '이상희', '정종순', '민유숙', '김수남', '김동연', '박준홍', '김동철', '김상돈', '이병환', '황선봉', '김정섭', '손지열', '김정호', '오세훈', '한범덕', '김종량', '이인영', '최광수', '고
# ...

# %%
print(result_list2.index('신재민신재희 존나 잘생겼을까'))

# %%
# 데이터프레임 b의 index리스트 확인
index_list2=list(b.index)
print(index_list2)

# %%
#result_list2를 _id자리에 집어넣기

b['_id']=result_list2

# %%
#한자를 제외한 _id column을 가진 dataframe을 b로 재설정
print(b)

# %%
b=b.drop(b.index[4])
print(b)

# %%
b=b.drop(b.index[376])
print(b)

# %%
print(list(b['종교']))
# Out:
# ['개신교', '개신교', '기독교', nan, nan, '개신교[2][3]', nan, nan, '천주교[1]', nan, '불교(민주당 연등회 부회장 역임, 천주교 세례명: 유스토)[1] → 무교(대통령 프로필)[2] → 불교[3]', '천주교 (세례명: 바오로)', '천주교 (세례명\xa0: 다니엘)', '감리교', nan, '개신교(예장통합)[1]', nan, '개신교', '개신교(장로회)', '개신교(한국기독교장로회)', nan, nan, '천주교 (세례명: 마르코)', '개신교', '개신교(예장통합)', nan, '개신교', nan, '개신교', nan, '개신교(예장통합)[1]', nan, nan, '개신교(장로회)', nan, '개신교', '개신교(장로회)', '무종교', '개신교', '개신교[1]', nan, '불교', '천주교(세례명: 마카리오)', '무종교', '개신교(한국기독교장로회)', '천주교(세례명: 고르넬리오)', nan, '개신교(감리교)', '개신교(예장합동)', nan, '개신교(한국기독교장로회)[1]', '개신교(장로회)', '불교(민주당 연등회 부회장 역임, 천주교 세례명: 유스토)[1] → 무교(대통령 프로필)[2] → 불교[3]', '기독교', '개신교', '개신교(한국기독교장로회)', '천주교(세례명: 피델리스)', nan, '개신교(한국기독교장로회)', '무종교', '불교', '개신교(예장합동)', '천주교(영세명: 스테파노)', '개신교(침례회)', '개신교(예장통합)[1]', '개신교', nan, '개신교', '개신교', '천주교(세례명: 요셉)', '캐토릭', nan, '천주교', nan, '천주교(세례명: 프란치스코 하비에르)', nan, '천주교(세례명: 바오로)', nan, '개신교', '천주교(영세명: 요셉)', '개신교(장로회)', nan, nan, '불교', nan, nan, '성공회', nan, '개신교', '원불교', nan, '개신교', nan, nan, '천주교(세례명: 이냐시오 데 로욜라
# ...

# %%
#종교 데이터 중에서 괄호 및 괄호 안의 문자 제거 

r=b['종교'].str.replace(r"\(.*\)","")
print(r)
# Out:
# 1         개신교
# 7         개신교
# 9         기독교
# 15        NaN
# 31        NaN
#          ...
# 48071     무종교
# 48483     NaN
# 49019    천주교
# 49270     NaN
# 49465     NaN
# Name: 종교, Length: 410, dtype: object

# %%
print(list(r))
r=list(r)
# Out:
# ['개신교', '개신교', '기독교', nan, nan, '개신교[2][3]', nan, nan, '천주교[1]', nan, '불교[2] → 불교[3]', '천주교 ', '천주교 ', '감리교', nan, '개신교[1]', nan, '개신교', '개신교', '개신교', nan, nan, '천주교 ', '개신교', '개신교', nan, '개신교', nan, '개신교', nan, '개신교[1]', nan, nan, '개신교', nan, '개신교', '개신교', '무종교', '개신교', '개신교[1]', nan, '불교', '천주교', '무종교', '개신교', '천주교', nan, '개신교', '개신교', nan, '개신교[1]', '개신교', '불교[2] → 불교[3]', '기독교', '개신교', '개신교', '천주교', nan, '개신교', '무종교', '불교', '개신교', '천주교', '개신교', '개신교[1]', '개신교', nan, '개신교', '개신교', '천주교', '캐토릭', nan, '천주교', nan, '천주교', nan, '천주교', nan, '개신교', '천주교', '개신교', nan, nan, '불교', nan, nan, '성공회', nan, '개신교', '원불교', nan, '개신교', nan, nan, '천주교', nan, '천주교 ', '감리교', '개신교', nan, '불교', '천주교', nan, nan, nan, nan, nan, nan, '천주교', nan, '개신교[2]', '개신교[1]', '천주교', nan, nan, '불교', nan, nan, '개신교', nan, '불교', '천주교', nan, nan, nan, nan, nan, nan, nan, nan, nan, '개신교', nan, nan, nan, nan, nan, '개신교', '천주교 ', nan, '개신교', '개신교[1][2]', nan, nan, nan, nan, nan, nan, nan, '개신교', '개신교', nan, '개신교', '천주교', na
# ...

# %%
b['종교']=r

# %%
print(b)
# Out:
#        Unnamed: 0  _id             웹사이트    종교  \
# 1               1  송하진          송하진 트위터   개신교
# 7               7  김준성              NaN   개신교
# 9               9  정홍원              NaN   기독교
# 15             15  강임준              NaN   NaN
# 31             31  NaN          Tatu.ru   NaN
# ...           ...  ...              ...   ...
# 48071       48071  이승훈  스타빌리지엔터테인먼트 이승훈   무종교
# 48483       48483   이훈              NaN   NaN
# 49019       49019  이동우      이동우 네이버 블로그  천주교
# 49270       49270  김진규              NaN   NaN
# 49465       49465  박삼기            보트 비전   NaN
#
#                                                       경력    국적      배우자  \
# 1                                                   전주시장  대한민국      오경진
# 7                                                    NaN  대한민국      NaN
# 9      제27대 법무연수원장, 광주지방검찰청 검사장, 부산지방검찰청 검사장, 제9대 대한법...  대한민국  최옥자(재혼)
# 15                                       제6~7대 전라북도의회 의원  대한민국      NaN
# ...

# %%
rr=b['종교'].str.replace("[","(")
print(rr)
rr=list(rr)
# Out:
# 1         개신교
# 7         개신교
# 9         기독교
# 15        NaN
# 31        NaN
#          ...
# 48071     무종교
# 48483     NaN
# 49019    천주교
# 49270     NaN
# 49465     NaN
# Name: 종교, Length: 410, dtype: object

# %%
b['종교']=list(rr)

# %%
print(b)
print(list(b['종교']))
# Out:
#        Unnamed: 0  _id             웹사이트    종교  \
# 1               1  송하진          송하진 트위터   개신교
# 7               7  김준성              NaN   개신교
# 9               9  정홍원              NaN   기독교
# 15             15  강임준              NaN   NaN
# 31             31  NaN          Tatu.ru   NaN
# ...           ...  ...              ...   ...
# 48071       48071  이승훈  스타빌리지엔터테인먼트 이승훈   무종교
# 48483       48483   이훈              NaN   NaN
# 49019       49019  이동우      이동우 네이버 블로그  천주교
# 49270       49270  김진규              NaN   NaN
# 49465       49465  박삼기            보트 비전   NaN
#
#                                                       경력    국적      배우자  \
# 1                                                   전주시장  대한민국      오경진
# 7                                                    NaN  대한민국      NaN
# 9      제27대 법무연수원장, 광주지방검찰청 검사장, 부산지방검찰청 검사장, 제9대 대한법...  대한민국  최옥자(재혼)
# 15                                       제6~7대 전라북도의회 의원  대한민국      NaN
# ...

# %%
rrr=b['종교'].str.replace("]",")")
print(rrr)
rrr=list(rrr)
# Out:
# 1         개신교
# 7         개신교
# 9         기독교
# 15        NaN
# 31        NaN
#          ...
# 48071     무종교
# 48483     NaN
# 49019    천주교
# 49270     NaN
# 49465     NaN
# Name: 종교, Length: 410, dtype: object

# %%
b['종교']=list(rrr)

# %%
print(b)
print(list(b['종교']))
# Out:
#        Unnamed: 0  _id             웹사이트    종교  \
# 1               1  송하진          송하진 트위터   개신교
# 7               7  김준성              NaN   개신교
# 9               9  정홍원              NaN   기독교
# 15             15  강임준              NaN   NaN
# 31             31  NaN          Tatu.ru   NaN
# ...           ...  ...              ...   ...
# 48071       48071  이승훈  스타빌리지엔터테인먼트 이승훈   무종교
# 48483       48483   이훈              NaN   NaN
# 49019       49019  이동우      이동우 네이버 블로그  천주교
# 49270       49270  김진규              NaN   NaN
# 49465       49465  박삼기            보트 비전   NaN
#
#                                                       경력    국적      배우자  \
# 1                                                   전주시장  대한민국      오경진
# 7                                                    NaN  대한민국      NaN
# 9      제27대 법무연수원장, 광주지방검찰청 검사장, 부산지방검찰청 검사장, 제9대 대한법...  대한민국  최옥자(재혼)
# 15                                       제6~7대 전라북도의회 의원  대한민국      NaN
# ...

# %%
#종교 데이터 중에서 괄호 및 괄호 안의 문자 제거 
rrr=b['종교'].str.replace(r"\(.*\)","")
print(rrr)
# Out:
# 1         개신교
# 7         개신교
# 9         기독교
# 15        NaN
# 31        NaN
#          ...
# 48071     무종교
# 48483     NaN
# 49019    천주교
# 49270     NaN
# 49465     NaN
# Name: 종교, Length: 410, dtype: object

# %%
print(list(rrr))
rrr=list(rrr)
# Out:
# ['개신교', '개신교', '기독교', nan, nan, '개신교', nan, nan, '천주교', nan, '불교', '천주교 ', '천주교 ', '감리교', nan, '개신교', nan, '개신교', '개신교', '개신교', nan, nan, '천주교 ', '개신교', '개신교', nan, '개신교', nan, '개신교', nan, '개신교', nan, nan, '개신교', nan, '개신교', '개신교', '무종교', '개신교', '개신교', nan, '불교', '천주교', '무종교', '개신교', '천주교', nan, '개신교', '개신교', nan, '개신교', '개신교', '불교', '기독교', '개신교', '개신교', '천주교', nan, '개신교', '무종교', '불교', '개신교', '천주교', '개신교', '개신교', '개신교', nan, '개신교', '개신교', '천주교', '캐토릭', nan, '천주교', nan, '천주교', nan, '천주교', nan, '개신교', '천주교', '개신교', nan, nan, '불교', nan, nan, '성공회', nan, '개신교', '원불교', nan, '개신교', nan, nan, '천주교', nan, '천주교 ', '감리교', '개신교', nan, '불교', '천주교', nan, nan, nan, nan, nan, nan, '천주교', nan, '개신교', '개신교', '천주교', nan, nan, '불교', nan, nan, '개신교', nan, '불교', '천주교', nan, nan, nan, nan, nan, nan, nan, nan, nan, '개신교', nan, nan, nan, nan, nan, '개신교', '천주교 ', nan, '개신교', '개신교', nan, nan, nan, nan, nan, nan, nan, '개신교', '개신교', nan, '개신교', '천주교', nan, nan, '천주교', '불교', nan, nan, nan, '천주교', '성공회', '불교', na
# ...

# %%
b['종교']=list(rrr)

# %%
print(list(b['종교']))
# Out:
# ['개신교', '개신교', '기독교', nan, nan, '개신교', nan, nan, '천주교', nan, '불교', '천주교 ', '천주교 ', '감리교', nan, '개신교', nan, '개신교', '개신교', '개신교', nan, nan, '천주교 ', '개신교', '개신교', nan, '개신교', nan, '개신교', nan, '개신교', nan, nan, '개신교', nan, '개신교', '개신교', '무종교', '개신교', '개신교', nan, '불교', '천주교', '무종교', '개신교', '천주교', nan, '개신교', '개신교', nan, '개신교', '개신교', '불교', '기독교', '개신교', '개신교', '천주교', nan, '개신교', '무종교', '불교', '개신교', '천주교', '개신교', '개신교', '개신교', nan, '개신교', '개신교', '천주교', '캐토릭', nan, '천주교', nan, '천주교', nan, '천주교', nan, '개신교', '천주교', '개신교', nan, nan, '불교', nan, nan, '성공회', nan, '개신교', '원불교', nan, '개신교', nan, nan, '천주교', nan, '천주교 ', '감리교', '개신교', nan, '불교', '천주교', nan, nan, nan, nan, nan, nan, '천주교', nan, '개신교', '개신교', '천주교', nan, nan, '불교', nan, nan, '개신교', nan, '불교', '천주교', nan, nan, nan, nan, nan, nan, nan, nan, nan, '개신교', nan, nan, nan, nan, nan, '개신교', '천주교 ', nan, '개신교', '개신교', nan, nan, nan, nan, nan, nan, nan, '개신교', '개신교', nan, '개신교', '천주교', nan, nan, '천주교', '불교', nan, nan, nan, '천주교', '성공회', '불교', na
# ...

# %%
#try except을 사용해서 종교 뽑아내기

index_listb=list(b.index)
result_listb=[]

for temp_indexb in index_listb:
    temp_datab=b.loc[temp_indexb,:].copy()
    
    try:
        temp_datab['종교']=temp_datab['종교'][-4:]
        result_listb.append(temp_datab['종교'])
    
    except:
        result_listb.append('no result')

print(result_listb)
# Out:
# ['개신교', '개신교', '기독교', 'no result', 'no result', '개신교', 'no result', 'no result', '천주교', 'no result', '불교', '천주교 ', '천주교 ', '감리교', 'no result', '개신교', 'no result', '개신교', '개신교', '개신교', 'no result', 'no result', '천주교 ', '개신교', '개신교', 'no result', '개신교', 'no result', '개신교', 'no result', '개신교', 'no result', 'no result', '개신교', 'no result', '개신교', '개신교', '무종교', '개신교', '개신교', 'no result', '불교', '천주교', '무종교', '개신교', '천주교', 'no result', '개신교', '개신교', 'no result', '개신교', '개신교', '불교', '기독교', '개신교', '개신교', '천주교', 'no result', '개신교', '무종교', '불교', '개신교', '천주교', '개신교', '개신교', '개신교', 'no result', '개신교', '개신교', '천주교', '캐토릭', 'no result', '천주교', 'no result', '천주교', 'no result', '천주교', 'no result', '개신교', '천주교', '개신교', 'no result', 'no result', '불교', 'no result', 'no result', '성공회', 'no result', '개신교', '원불교', 'no result', '개신교', 'no result', 'no result', '천주교', 'no result', '천주교 ', '감리교', '개신교', 'no result', '불교', '천주교', 'no result', 'no result', 'no result', 'no result', 'no result', 'no result', '천주
# ...

# %%
#종교 데이터 중에서 괄호 및 괄호 안의 문자 제거 
rr=b['종교'].str.replace(r"\(.*\)","")
print(rr)

# %%
print(list(b['종교']))

# %%
#1. 국적 찾는 함수

def country(nation,df):
      
    p=df.dropna(subset=['정당'])
    index_listp=list(p.index)
    p=p.loc[index_listp,:]
    p=p.dropna(axis=1,how='all')
    n=p.dropna(subset=['국적'])


    index_list=list(n.index)
    result_list=[]
    
    for temp_index in index_list:
        temp_data=n.loc[temp_index,:]
        
        if temp_data['국적']==nation: 
            result_list.append(temp_index)
        else:
            pass
    
    return n.loc[result_list,:]

print(country('대한민국',df))
# Out:
#        Unnamed: 0  _id   국가   설립            웹사이트         종교   종류   표어   감독  \
# 1               1  송하진  NaN  NaN         송하진 트위터        개신교  NaN  NaN  NaN
# 3               3  전병헌  NaN  NaN         전병헌 블로그  개신교(예장고신)  NaN  NaN  NaN
# 6               6  신경민  NaN  NaN  신경민 - 트위터, 블로그         불교  NaN  NaN  NaN
# 7               7  김준성  NaN  NaN             NaN        개신교  NaN  NaN  NaN
# 9               9  정홍원  NaN  NaN             NaN        기독교  NaN  NaN  NaN
# ...           ...  ...  ...  ...             ...        ...  ...  ...  ...
# 49134       49134  김종석  NaN  NaN           인스타그램     개신교[1]  NaN  NaN  NaN
# 49270       49270  김진규  NaN  NaN             NaN        NaN  NaN  NaN  NaN
# 49465       49465  박삼기  NaN  NaN           보트 비전        NaN  NaN  NaN  NaN
# 49650       49650  권영우  NaN  NaN             NaN        NaN  NaN  NaN  NaN
# 49729       49729  신은경  NaN  NaN             NaN        개신교  NaN  NaN  NaN
#
# ...

# %%
#2. 출생일 특정년도 이상(?) 찾고+ 생년월일 yyyymmdd로 바꾸는 함수


def birth(year,df):
    
#     p=df.dropna(subset=['정당'])
    p=df.dropna(subset=['출생일'])
    index_listp=list(p.index)
    p=p.loc[index_listp,:]
    p=p.dropna(axis=1,how='all')
    p=p.dropna(axis=1,thresh=800)
    
    birth_year=p['출생일'].astype(str).str[:4]
    birth_year=birth_year[birth_year.str.isdecimal()]
    birth_year=birth_year.astype(int)
    birth_year=birth_year[birth_year>=year]
    index_list1=birth_year.index.tolist() #index_list1=특정년도 이상(>=)에 해당하는 인덱스 리스트

    
    bb=p.loc[index_list1,:]
    index_list1=list(bb.index)
    result_list1=[]
    result_list11 = []
    for temp_index1 in index_list1:
        temp_data1=bb.loc[temp_index1,:]
    
        point=temp_data1['출생일'].find('(')
        point1=temp_data1['출생일'].find(')')
        target = temp_data1['출생일'][point+1:point1].strip().replace(' ','')
        
        if bool(re.match('.*-.*-.*',temp_data1['출생일'][point+1:point1].strip()))== True:
            z = temp_data1['출생일'][point+1:point1].replace('-','') 
            result_list1.append(temp_index1)
            result_list11.append(z)
        else:
            result_list11.append('no result')

    
    bb['출생일'] = result_list11
    return bb.loc[result_list1,:]

print(birth(1930,df))
# Out:
#        Unnamed: 0        _id   종교  \
# 1               1        송하진  개신교
# 7               7        김준성  개신교
# 9               9        정홍원  기독교
# 14             14        강인규  NaN
# 15             15        강임준  NaN
# ...           ...        ...  ...
# 49926       49926  타데우스 즈비아텍  NaN
# 49935       49935       존 토샥  NaN
# 49948       49948      셰인 카윈  NaN
# 49979       49979        이홍기  NaN
# 49983       49983    엔리케 세레누  NaN
#
#                                                       경력    국적      배우자  \
# 1                                                   전주시장  대한민국      오경진
# 7                                                    NaN  대한민국      NaN
# 9      제27대 법무연수원장, 광주지방검찰청 검사장, 부산지방검찰청 검사장, 제9대 대한법...  대한민국  최옥자(재혼)
# 14                                                   NaN   NaN      NaN
# 15                                       제6~7대 전라북도의회 의원  대한민국      NaN
# ...                                                  ...   ...      ...
# ...

# %%
#3. 이름 한글만 뽑아내기

def names(name,df):
    p=df.dropna(subset=['출생일'])
    index_listp=list(p.index)
    p=p.loc[index_listp,:]
    p=p.dropna(axis=1,how='all')
    p=p.dropna(axis=1,thresh=800)

    result_list2=[]
    index_list2=list(p.index)

    for temp_index2 in index_list2:
        
        if name=='한글':
        
            temp_data2=p.loc[temp_index2,:].copy()
            temp_data2['_id']=str( temp_data2['_id'])
            hangul = re.compile('[^ ㄱ-ㅣ가-힣]+')
            h=hangul.sub('',temp_data2['_id'])
            result_list2.append(h)          #result_list2에 h를 append하는것=temp_data2의 _id중에 한글문자만 append

        elif name=='영어':
            
            temp_data2=p.loc[temp_index2,:].copy()
            temp_data2['_id']=str( temp_data2['_id'])
            eng = re.compile('[^a-zA-Z0-9]')
            e=eng.sub('',temp_data2['_id'])
            result_list2.append(e)

        else:
            pass
    
    p['_id'] = result_list2              #그렇게 append해서 만든 list를 p['_id']로 치환하기
    return p
print(names('한글',df))
# Out:
#        Unnamed: 0        _id                       종교  \
# 1               1        송하진                      개신교
# 7               7        김준성                      개신교
# 9               9        정홍원                      기독교
# 13             13        함태영  유교(성리학) → 개신교(한국기독교장로회)
# 14             14        강인규                      NaN
# ...           ...        ...                      ...
# 49926       49926  타데우스 즈비아텍                      NaN
# 49935       49935       존 토샥                      NaN
# 49948       49948      셰인 카윈                      NaN
# 49979       49979        이홍기                      NaN
# 49983       49983    엔리케 세레누                      NaN
#
#                                                       경력    국적  \
# 1                                                   전주시장  대한민국
# 7                                                    NaN  대한민국
# 9      제27대 법무연수원장, 광주지방검찰청 검사장, 부산지방검찰청 검사장, 제9대 대한법...  대한민국
# ...

# %%
#4.  종교 예쁘게 만들기 완성

hangul = re.compile('[^ ㄱ-ㅣ가-힣  ]+')

def religion(df):
    p=df.dropna(subset=['정당'])
    index_listp=list(p.index)
    p=p.loc[index_listp,:]
    p=p.dropna(axis=1,how='all')
    p=p.dropna(axis=1,thresh=800)
    
    #for1
    index_list3=list(p.index)
    result_list = []
    for temp_index3 in index_list3:
        try:
            temp_data3=p.loc[temp_index3,:]
            r=temp_data3['종교'].replace("[","(").replace("]",")").replace("{","(").replace("}",")").replace(" ","")
            r=re.sub(r'\([^)]*\)', '', r).replace(')','').replace('(','')
            result_list.append(r) 
        except:
            result_list.append('no result')
    
    p['종교']=result_list
    
    #for2
    result_list1=[]
    for temp_result in result_list:
        if bool(re.match('.*→.*',temp_result)) == True:
            point = [i.start() for i in re.finditer('→',temp_result)]
            result_list1.append(temp_result[point[-1]+1:].strip())
        else:
            result_list1.append(temp_result)
    
    p['종교']=result_list1
    
    #for3
    result_list2=[]
    for r in result_list1:
        if "개신교" in r:
            r=r.replace(r,"기독교")
            result_list2.append(r)
            
        elif "성공회" in r:
            r=r.replace(r,"성공회")
            result_list2.append(r)
            
        elif "카톨릭" in r:
            r=r.replace(r,"카톨릭")
            result_list2.append(r)            
        
        elif "가톨릭" in r:    
            r=r.replace(r,"카톨릭")
            result_list2.append(r)    

        elif "무교" in r:    
            r=r.replace(r,"무교")
            result_list2.append(r)                

        elif "무종교" in r:    
            r=r.replace(r,"무교")
            result_list2.append(r)   
            
        elif "무신론" in r:    
            r=r.replace(r,"무교")
            result_list2.append(r)                   

        elif "이슬람" in r:    
            r=r.replace(r,"이슬람교")
            result_list2.append(r)             
        
        elif "정교" in r:    
            r=r.replace(r,"정교회")
            result_list2.append(r)  
        
        elif "없음" in r:    
            r=r.replace(r,"no result")
            result_list2.append(r)                          
            
        else:
            result_list2.append(r)
     
    p['종교']=result_list2
   
    

    return p

print(list(religion(df)['종교']))
# Out:
# ['기독교', '기독교', '불교', '기독교', '기독교', '기독교', 'no result', 'no result', 'no result', 'no result', '기독교', '기독교', 'no result', 'no result', '천주교', 'no result', '불교', '천주교', '유교', '천주교', '기독교', '유학', 'no result', '기독교', '기독교', '기독교', '기독교', '기독교', '천주교', '불교,원불교', 'no result', '천주교', '유교', '유교', '감리교', '천주교', 'no result', 'no result', 'no result', 'no result', '천주교', '기독교', '기독교', '무교', '천주교', 'no result', '천주교', '기독교', '천주교', '기독교', '기독교', '무교', '유교', '기독교', '기독교', 'no result', '유교', '기독교', '기독교', 'no result', '천주교', '천주교', '천주교', '무교', 'no result', '기독교', '기독교', 'no result', 'no result', 'no result', '천주교', '기독교', '기독교', '기독교', 'no result', '천주교', '유학', 'no result', '무교', '기독교', 'no result', '천주교', 'no result', '기독교', '카톨릭', 'no result', '기독교', '천주교', '기독교', 'no result', '기독교', 'no result', '천주교', 'no result', '기독교', '천주교', 'no result', 'no result', '천주교', '기독교', 'no result', '천주교', 'no result', '유교', 'no result', 'no result', 'no result', '기독교', '무교', '기독교', '기독교', '불교', '천주교', '기독교', 'n
# ...

# %%
import pandas as pd
univ_df=pd.read_excel('C:/Users/JalynneHEO/OneDrive - 주식회사 투디지트/바탕 화면/univ_list.xlsx', engine = 'openpyxl')
print(univ_df)
# Out:
#       Unnamed: 0        _id  \
# 0              1      기술대학교
# 1              2    토지주택대학교
# 2              3      라발대학교
# 3              4    몬트리올대학교
# 4              5  자와할랄네루대학교
# ...          ...        ...
# 1007        1008    광주과학기술원
# 1008        1009  대구경북과학기술원
# 1009        1010    울산과학기술원
# 1010        1011    한국과학기술원
# 1011        1012    한국과학기술원
#
#                                                      위치             설립    국가  \
# 0                                                   NaN            NaN   NaN
# 1                               대전광역시 유성구 엑스포로 539번길 99      2012년 10월  대한민국
# 2                                              퀘벡주 퀘벡 시          1663년   캐나다
# 3                                             퀘백 주 몬트리올          1878년   캐나다
# 4                                                   NaN           1969   NaN
# ...                                                 ...            ...   ...
# 1007                                           광주광역시 북구  1993년 11월 17일  대한민국
# ...

# %%
#5. 출생일이 있는 데이터 중 정당을 예쁘게 찾고 학력 정리하기

import re

def party(df):
    p=df.dropna(subset=['출생일'])
    index_listp=list(p.index)
    p=p.loc[index_listp,:]
    p=p.dropna(axis=1,how='all')
    p=p.dropna(axis=1,thresh=800)
    
    #for1
    index_list3=list(p.index)
    result_list = []
    for temp_index3 in index_list3:
        try:
            temp_data3=p.loc[temp_index3,:]
            r=temp_data3['정당'].replace("[","(").replace("]",")").replace("{","(").replace("}",")").replace(" ","")
            r=re.sub(r'\([^)]*\)', '', r).replace(')','').replace('(','')
            result_list.append(r) 
        except:
            result_list.append(r)
    
    p['정당']=result_list
    
    #for 2
    result_list1=[]
    for temp_result in result_list:
        if bool(re.match('.*→.*',temp_result)) == True:
            point = [i.start() for i in re.finditer('→',temp_result)]
            result_list1.append(temp_result[point[-1]+1:].strip())
        else:
            result_list1.append(temp_result)
    
    p['정당']=result_list1    
    
    #for 3 특수문자 없애기
    result_list2=[]
    for s in result_list1:
        try:
            s=re.sub(r'[^ ㄱ-ㅣ가-힣A-Za-z]', '', s) 
            result_list2.append(s)
        except:
            result_list2.append(s)
    p['정당']=result_list2    
    
    
    #for 4 학력 빈칸 다 없앰
    result_list4 = []
    for temp_index3 in index_list3:
        try:
            temp_data3=p.loc[temp_index3,:]
            s=temp_data3['학력'].replace(" ","")
            result_list4.append(s) 
        except:
            result_list4.append(temp_data3['학력'])
    
    p['학력']=result_list4

   #for 5 univ 이름 append하기
    index_list=list(univ_df.index)
    univ_list=[]
    for temp_index in index_list:
        temp_data=univ_df.loc[temp_index,:]
        pp=temp_data['_id']
        univ_list.append(pp)
    
  
    final=[]
    for b in list(p['학력']):
        flag = 0
        try:    
            for a in univ_list:
                if a in b:
                    final.append(a)
                    flag = 1
                    break
                else:
                    pass
        except:
            pass
        
        if flag == 0:
            final.append('no result')

    #print(len(final))
    #print(len(p['학력']))
    
    p['학력']=final                 
    print(final)
    
    return p 

    print(list(index(p['학력'])))
     
print(party(df))
# Out:
# ['고려대학교', 'no result', '성균관대학교', 'no result', '초당대학교', '한국외국어대학교', 'no result', 'no result', 'no result', '성균관대학교', '서울대학교', 'no result', '경희대학교', '전남대학교', 'no result', '단국대학교', 'no result', '서울대학교', 'no result', '서울대학교', '경희대학교', 'no result', '워싱턴대학교', 'no result', '가톨릭대학교', '전남대학교', 'no result', 'no result', 'no result', '단국대학교', 'no result', '전남대학교', 'no result', '서울대학교', '경희대학교', 'no result', '서울대학교', 'no result', 'no result', '건국대학교', 'no result', 'no result', '경희대학교', 'no result', '컬럼비아대학교', '이화여자대학교', '서울대학교', 'no result', 'no result', '육군대학교', '서울대학교', 'no result', 'no result', '서울대학교', 'no result', '조선대학교', 'no result', '서울대학교', '성균관대학교', '서울대학교', 'no result', '국방대학교', '고려대학교', 'no result', 'no result', 'no result', '서울대학교', '서울대학교', 'no result', 'no result', '프린스턴대학교', '서강대학교', 'no result', '서울대학교', '서울대학교', '전남과학대학교', '서울대학교', '서울대학교', '한양대학교', 'no result', '서울대학교', 'no result', '동의대학교', 'no result', '뮌스터대학교', '한양대학교', 'no result', 'no result', 'no result', 'no result', 'n
# ...

# %%
#8 social event 함수로 만들기

import re
import numpy as np
import pandas as pd
from tqdm import tqdm

def social_event(df):
    df=df.dropna(axis=1,how='all')
    df_list=list(df.index) 
    events=['대선','올림픽','월드컵','아시안 게임']
    
    temp_list=[]
    for b in tqdm(df.index):
        temp_data=df.loc[b,:].copy()   
        
        values=[]   
        for key in temp_data.keys():
            if str(temp_data[key]) != 'nan':
                values.append(temp_data[key])
        flag=0            
        for e in events:
            for v in values:
                try :
                    v=v.replace(' ','')
                    if e in v:
                        temp_list.append(b)
                        flag=1
                        break
                    else:
                        pass
                except:
                    pass
            if flag==1:
                break
            else:
                pass
    df=df.loc[temp_list,:]
    
    df=df.query('`개최 도시`.notnull() or 참가국.notnull() or 경력.notnull() or `참가 선수`.notnull() or 대회.notnull()')
    
    #[폐막식] mm월 dd일로 만들기
    result_list=[]
    for aa in list(df['폐막식']):
        
        try:
            aa=aa.replace(' ','')
            
            point=aa.find('년') 
            point1=aa.find('월')
            point2=aa.find('일')
        
            try:
                if len(aa[point+1:point1])==1: 
                    aa=aa[:point+1]+'0'+aa[point1-1:]
                    
                    if len(aa[point1+2:point2+1]) == 1: #월이 한자리 이면서 일이 한자리이면
                        aa=aa[:point1+2]+'0'+aa[point2:]
                        result_list.append(aa)
                        
                    else: #월이 한자리이면서 일이 두자리이면
                        result_list.append(aa)
                
                else: #월이 두자리이면
                    aa=aa[:point1+1]+'0'+aa[point2-1:]
                    result_list.append(aa)
            except:
                result_list.append(aa)
        except:
            result_list.append(aa)
    
    df['폐막식']=result_list
    
    #괄호 없애고 년월일 없애기
    result_list1=[]
    for aaa in list(df['폐막식']):
        try:
            aaa=re.sub(r'\([^)]*\)', '',aaa)
            aaa=aaa.replace("개최되지않음","").replace("년","").replace("월","").replace("일","")
            result_list1.append(aaa)
        except:
            result_list1.append(aaa)
    df['폐막식']=result_list1
    
    #[개회식] mm월 dd일로 만들기
    
    result_list2=[]
    for bb in list(df['개회식']):
        
        try:
            bb=bb.replace(' ','')
            
            point=bb.find('년') 
            point1=bb.find('월')
            point2=bb.find('일')
            
            try:
                if len(bb[point+1:point1])==1: 
                    bb=bb[:point+1]+'0'+bb[point1-1:]
                    
                    if len(bb[point1+2:point2+1]) == 1: 
                        bb=bb[:point1+2]+'0'+bb[point2:]
                        result_list2.append(bb)
                        
                    else: 
                        result_list2.append(bb)
                
                else: 
                    bb=bb[:point1+1]+'0'+bb[point2-1:]
                    result_list2.append(bb)
            except:
                result_list2.append(bb)
        except:
            result_list2.append(bb)
    
    df['개회식']=result_list2
    
    result_list3=[]
    for bbb in list(df['폐막식']):
        try:
            bbb=re.sub(r'\([^)]*\)', '',bbb)
            bbb=bbb.replace("개최되지않음","").replace("년","").replace("월","").replace("일","")
            result_list3.append(bbb)
        except:
            result_list3.append(bbb)
    df['개회식']=result_list3
    
    #[폐회식] mm월 dd일로 만들기
    result_list4=[]
    for cc in list(df['폐회식']):
        
        try:
            cc=cc.replace(' ','')
            
            point=cc.find('년') 
            point1=cc.find('월')
            point2=cc.find('일')
        
            try:
                if len(cc[point+1:point1])==1: 
                    cc=cc[:point+1]+'0'+cc[point1-1:]
                    
                    if len(cc[point1+2:point2+1]) == 1: 
                        cc=cc[:point1+2]+'0'+cc[point2:]
                        result_list4.append(cc)
                        
                    else: 
                        result_list4.append(cc)
                
                else: 
                    cc=cc[:point1+1]+'0'+cc[point2-1:]
                    result_list4.append(cc)
            except:
                result_list4.append(cc)
        except:
            result_list4.append(cc)
    
    df['폐회식']=result_list4
    
    #괄호 없애고 년월일 없애기
    result_list5=[]
    for ccc in list(df['폐회식']):
        try:
            ccc=re.sub(r'\([^)]*\)', '',ccc)
            ccc=ccc.replace("년","").replace("월","").replace("일","")
            result_list5.append(ccc)
        except:
            result_list5.append(ccc)
    df['폐회식']=result_list5
    
    return list(df['폐회식']) 

print(social_event(df))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 50000/50000 [05:54<00:00, 141.08it/s]
# ...

# %%
p=df.dropna(subset=['출생일'])
print(type(list(p['학력'])))
# Out:
# <class 'list'>

# %%
#6. 출생일이 있는 데이터 중 정당을 예쁘게 찾아내기
import re
def party(df):
    p=df.dropna(subset=['출생일'])
    index_listp=list(p.index)
    p=p.loc[index_listp,:]
    p=p.dropna(axis=1,how='all')
    p=p.dropna(axis=1,thresh=800)
    
    #for1
    index_list3=list(p.index)
    result_list = []
    for temp_index3 in index_list3:
        try:
            temp_data3=p.loc[temp_index3,:]
            r=temp_data3['정당'].replace("[","(").replace("]",")").replace("{","(").replace("}",")").replace(" ","")
            r=re.sub(r'\([^)]*\)', '', r).replace(')','').replace('(','')
            result_list.append(r) 
        except:
            result_list.append(r)
    
    p['정당']=result_list
    
    #for 2
    result_list1=[]
    for temp_result in result_list:
        if bool(re.match('.*→.*',temp_result)) == True:
            point = [i.start() for i in re.finditer('→',temp_result)]
            result_list1.append(temp_result[point[-1]+1:].strip())
        else:
            result_list1.append(temp_result)
    
    p['정당']=result_list1    
    
    #for 3 특수문자 없애기
    result_list2=[]
    for s in result_list1:
        try:
            s=re.sub(r'[^ ㄱ-ㅣ가-힣A-Za-z]', '', s) 
            result_list2.append(s)
        except:
            result_list2.append(s)
    p['정당']=result_list2    

    return p    

print(list(party(df)['정당']))
# Out:
# ['더불어민주당', '더불어민주당', '무소속', '무소속', '더불어민주당', '더불어민주당', '더불어민주당', '민주공화당', '민주공화당', '국민의힘', '무소속', '더불어민주당', '더불어민주당', '더불어민주당', '무소속', '국민의힘', '서인잔존후예노론세력', '국민의힘', '국민의힘', '국민의힘', '민주당', '서인세력', '자유당', '민주국민당', '민주당', '더불어민주당', '더불어민주당', '서인잔존후예노론세력', '무소속', '더불어민주당', '무소속', '더불어민주당', '무소속', '무소속', '더불어민주당', '조선로동당', '조선로동당', '무소속', '새천년민주당무소속', '더불어민주당', '더불어민주당', '더불어민주당', '조선로동당', '무소속', '무소속', '더불어민주당', '미래통합당', '노론세력', '노론세력', '무소속', '무소속', '무소속', '민주국민당', '민주국민당', '민주국민당', '더불어민주당', '중국공산당', '무소속', '더불어민주당', '더불어민주당', '더불어민주당', '무소속', '무소속', '서인후예성향노론세력', '중국공산당', '중국공산당', '미래통합당', '더불어민주당', '더불어민주당', '더불어민주당', '무소속', '자유한국당', '국민의당', '국민의당', '국민의힘', '더불어민주당', '무소속', '무소속', '더불어민주당', '무소속', '미래한국당', '서인세력후예', '무소속', '무소속', '국민의힘', '열린민주당', '열린민주당', '열린민주당', '열린민주당', '열린민주당', '열린민주당', '열린민주당', '무소속', '무소속', '무소속', '무소속', '무소속', '무소속', '무소속', '무소속', '무소속', '무소속', '무소속', '무소속', '무소속', '무소속', '무소속', '무소속', '무소속', '무소속', '무소속', '소론후예세력', '서인세력잔존후예', '서인세력잔존후예', '서인세력잔존후예', '서인세력잔존후
# ...

# %%
#7. 정당 정보만 가져오기
import re
def party_info(df):
    
    p=df.dropna(subset=['이념'])
    p=p.dropna(axis=1,how='all')
    p=p.dropna(axis=1,thresh=10)
    
    index_listp=list(p.index)
    result_list=[]
    
    #[이념] 괄호 없애기
    for temp_index in index_listp:
        try:
            temp_data=p.loc[temp_index,:]
            a=temp_data['이념'].replace("[","(").replace("]",")")
            a=re.sub(r'\([^)]*\)', '', a).replace(')','').replace('(','')
            result_list.append(a) 
        except:
            result_list.append(a)
    
    p['이념']=result_list        
    
    #[이념]특수문자 없애기
    result_list1=[]
    for b in result_list:
        try:
            b=re.sub(r'[^ ㄱ-ㅣ가-힣A-Za-z]', '', b) 
            result_list2.append(b)
        except:
            result_list1.append(b)
    p['이념']=result_list1   
    
    #[_id] 괄호없애기
    result_list2=[]
    for temp_index1 in index_listp:
        try:
            temp_data1=p.loc[temp_index1,:]
            c=temp_data1['_id'].replace("[","(").replace("]",")")
            c=re.sub(r'\([^)]*\)', '', c).replace(')','').replace('(','')
            result_list2.append(c) 
        except:
            result_list2.append(c)
    
    p['_id']=result_list2    
    
    #[_id] 한글만 가져오기
    result_list3=[]
    for temp_index2 in index_listp:
        try:
            temp_data2=p.loc[temp_index2,:].copy()
            temp_data2['_id']=str(temp_data2['_id'])
            hangul = re.compile('[^ ㄱ-ㅣ가-힣]+')
            h=hangul.sub('',temp_data2['_id'])
            result_list3.append(h)
        except:
            result_list3.append(temp_data2['_id'])
    
    p['_id']=result_list3
    
    #'창당' 괄호 없애기
    result_list4=[]
    for temp_index3 in index_listp:
        try:
            temp_data3=p.loc[temp_index3,:]
            d=temp_data3['창당'].replace("[","(").replace("]",")")
            d=re.sub(r'\([^)]*\)', '', d).replace(')','').replace('(','')
            result_list4.append(d) 
        except:
            result_list4.append(d)
    
    p['창당']=result_list4    
    

    #스펙트럼 []괄호 없애기
    result_list5=[]
    for temp_index4 in index_listp:
        try:
            temp_data4=p.loc[temp_index4,:]
            e=temp_data4['스펙트럼'].replace("[","(").replace("]",")").replace("{","(").replace("}",")").replace(" ","")
            e=re.sub(r'\([^)]*\)', '', e).replace(')','').replace('(','')
            result_list5.append(e) 
        except:
            result_list5.append(temp_data4['스펙트럼'])
    
    p['스펙트럼']=result_list5     
    p['스펙트럼']=p['스펙트럼'].fillna('no result')
    
    result_list6=[]
    for f in list(p['스펙트럼']):

        if "~중도좌파" in f:
            f=f.replace(f,"중도")
            result_list6.append(f)
        elif "~중도우파" in f:
            f=f.replace(f,"중도")
            result_list6.append(f)
        elif "~극우" in f:
            f=f.replace(f,"우익")
            result_list6.append(f) 
        elif "~우익" in f:
            f=f.replace(f,"중도우파")
            result_list6.append(f)
        elif "~좌익" in f:
            f=f.replace(f,"중도좌파")            
            result_list6.append(f) 
        elif "~우파" in f:
            f=f.replace(f,"중도좌파")            
            result_list6.append(f)             
        elif "~극좌" in f:
            f=f.replace(f,"좌파")
            result_list6.append(f) 
        elif "~좌파" in f:
            f=f.replace(f,"중도좌파")
            result_list6.append(f)             
        elif "1945" in f:
            f=f.replace(f,"우익")
            result_list6.append(f)
        elif ",극우" in f:
            f=f.replace(f,"우익")
            result_list6.append(f)
        elif "중도주의" in f:
            f=f.replace(f,"중도")
            result_list6.append(f)             
        else:
            result_list6.append(f)
        
    p['스펙트럼']=result_list6    
    
    # 상징색 괄호만 없앰
    result_list7=[]
    
    for temp_index6 in index_listp:
        try:
            temp_data6=p.loc[temp_index6,:]
            g=temp_data6['상징색'].replace("[","(").replace("]",")").replace(" ","").replace("-",",").replace("\n\xa0\xa0\xa0\xa0",",").replace("\xa0\xa0\xa0\xa0",",")
            g=re.sub(r'\([^)]*\)', '', g).replace(')','').replace('(','')
            result_list7.append(g) 
        except:
            result_list7.append(g)
    
    p['상징색']=result_list7    

    result_list8 = []
    for temp_elem in list(p['창당']):
        try:
            if temp_elem.find('년') == -1: # '년'이 없으면
                result_list8.append('no result') # no result
                continue
            else: #'년'이 있으면
                temp_elem = temp_elem.replace(' ','').strip() #'년'이 있으면 공백 없애주기
                count = [i.start() for i in re.finditer('년',temp_elem)] #뒤에서 '년'찾아준걸 count로 지정
                temp_elem = temp_elem[max(0,count[len(count)-1]-5):count[len(count)-1]+8] 
                # temp_elem = temp_elem.replace(' ','').strip() 
                hangul_numb = re.compile('[^가-힣 0-9]+') #정규표현식 한글만
                temp_elem = hangul_numb.sub('',temp_elem) #temp_elem에서 한글빼고 다 없애주기
               
                str1_, str2_, str3_ = '', '', '' # '' 형태를 str1_ str2_, str3_로 지정해주기  
                point1 = temp_elem.find('년') # temp_elem에서 '년'을 찾은 것을 point1
                str1_ = temp_elem[:point1] #'년' 앞에까지 가져온것=str1 = yyyy가 되겠지 아마도
                if temp_elem.find('월') != -1: #if '월'이 있으면
                    point2 = temp_elem.find('월') #temp_elem 에서 '월'을 찾은것 = point2 
                    str2_ = temp_elem[point1+1:point2] #'년' 뒤에서부터 월까지=str2 는 mm이 되겠지 아마도
                    if temp_elem.find('일') != -1: #'월'이 있는 것 중에 if'일'이 있으면  
                        point3 = temp_elem.find('일') #temp_elem 에서 '월'을 찾은것 = point3 
                        str3_ = temp_elem[point2+1 : point3] #'월' 뒤에서부터 '일'까지=str3 는 dd가 되겠지 아마도
                    else: #'일'이 없으면 pass
                        pass
                else: #'월'이 없으면 pass
                    pass
               
                if len(str2_) == 0: #if mm이 없으면
                    result_list8.append(str1_) # yyyy만 append
                    continue
                elif len(str2_) == 1: #else if mm이 한자리면 0추가해주기
                    str2_ = '0' + str2_
                else: #mm이 있으면 pass
                    pass
               
                if len(str3_) == 0: 
                    result_list8.append(str1_ + str2_)
                    continue
                elif len(str3_) == 1:
                    str3_ = '0' + str3_
                else:
                    pass
               
                result_list8.append(str1_ + str2_ + str3_)
               
                       
                   
        except:
            result_list8.append('no result')
            
    p['창당'] = result_list8
    

    
    return p

print(list(party_info(df)['창당']))
# Out:
# ['20080217', '20070805', '20121021', '20200205', '20200223', '20140326', '19971121', '20031111', '20170124', '20200308', '20050506', '19670207', '20200308', '20200223', '20140921', '20140217', '19511217', '20111207', '20200217', '20200119', '20111206', '20130721', '20200105', '20150808', '20200119', '20180213', '20150329', '19451010', '19950911', '19971010', '19971010', '18790502', '18540320', '19950330', '19950330', '18280108', '19810115', '20140326', '19900122', '195210', '19461123', '197303', '20150804', '19191010', '19191010', '19461009', '19551115', '20111010', '19041017', '1903', '19871130', '1917', '19860928', '20091001', '1848', '19981107', '19981107', '20170405', '19940708', '19200224', '1913', '19190105', '192504', '19711211', '19711211', '19460828', '1833', '1792', '19210723', '18590609', '1860', '20070928', '19210508', '19460208', '19870421', '19000227', '1918', '1918', '1834', '18890423', '18890423', '18980301', '19810920', '20081029', '19461123', '19710930', '190503', '
# ...

# %%
#7. 정당 정보만 가져오기
import re
def party_info(df):
    
    p=df.dropna(subset=['이념'])
    p=p.dropna(axis=1,how='all')
    p=p.dropna(axis=1,thresh=10)
    
    index_listp=list(p.index)
    result_list=[]
    
    #[이념] 괄호 없애기
    for temp_index in index_listp:
        try:
            temp_data=p.loc[temp_index,:]
            a=temp_data['이념'].replace("[","(").replace("]",")")
            a=re.sub(r'\([^)]*\)', '', a).replace(')','').replace('(','')
            result_list.append(a) 
        except:
            result_list.append(a)
    
    p['이념']=result_list        
    
    #[이념]특수문자 없애기
    result_list1=[]
    for b in result_list:
        try:
            b=re.sub(r'[^ ㄱ-ㅣ가-힣A-Za-z]', '', b) 
            result_list2.append(b)
        except:
            result_list1.append(b)
    p['이념']=result_list1   
    
    #[_id] 괄호없애기
    result_list2=[]
    for temp_index1 in index_listp:
        try:
            temp_data1=p.loc[temp_index1,:]
            c=temp_data1['_id'].replace("[","(").replace("]",")")
            c=re.sub(r'\([^)]*\)', '', c).replace(')','').replace('(','')
            result_list2.append(c) 
        except:
            result_list2.append(c)
    
    p['_id']=result_list2    
    
    #[_id] 한글만 가져오기
    result_list3=[]
    for temp_index2 in index_listp:
        try:
            temp_data2=p.loc[temp_index2,:].copy()
            temp_data2['_id']=str(temp_data2['_id'])
            hangul = re.compile('[^ ㄱ-ㅣ가-힣]+')
            h=hangul.sub('',temp_data2['_id'])
            result_list3.append(h)
        except:
            result_list3.append(temp_data2['_id'])
    
    p['_id']=result_list3
    
    #'창당' 괄호 없애기
    result_list4=[]
    for temp_index3 in index_listp:
        try:
            temp_data3=p.loc[temp_index3,:]
            d=temp_data3['창당'].replace("[","(").replace("]",")")
            d=re.sub(r'\([^)]*\)', '', d).replace(')','').replace('(','')
            result_list4.append(d) 
        except:
            result_list4.append(d)
    
    p['창당']=result_list4    
    
    
    #스펙트럼 []괄호 없애기
    result_list5=[]
    for temp_index4 in index_listp:
        try:
            temp_data4=p.loc[temp_index4,:]
            e=temp_data4['스펙트럼'].replace("[","(").replace("]",")").replace("{","(").replace("}",")").replace(" ","")
            e=re.sub(r'\([^)]*\)', '', e).replace(')','').replace('(','')
            result_list5.append(e) 
        except:
            result_list5.append(temp_data4['스펙트럼'])
    
    p['스펙트럼']=result_list5     
    p['스펙트럼']=p['스펙트럼'].fillna('no result')
    
    result_list6=[]
    for f in list(p['스펙트럼']):

        if "~중도좌파" in f:
            f=f.replace(f,"중도")
            result_list6.append(f)
        elif "~중도우파" in f:
            f=f.replace(f,"중도")
            result_list6.append(f)
        elif "~극우" in f:
            f=f.replace(f,"우익")
            result_list6.append(f) 
        elif "~우익" in f:
            f=f.replace(f,"중도우파")
            result_list6.append(f)
        elif "~좌익" in f:
            f=f.replace(f,"중도좌파")            
            result_list6.append(f) 
        elif "~우파" in f:
            f=f.replace(f,"중도우파")            
            result_list6.append(f)             
        elif "~극좌" in f:
            f=f.replace(f,"좌파")
            result_list6.append(f) 
        elif "~좌파" in f:
            f=f.replace(f,"중도좌파")
            result_list6.append(f)             
        elif "1945" in f:
            f=f.replace(f,"우익")
            result_list6.append(f)
        elif ",극우" in f:
            f=f.replace(f,"우익")
            result_list6.append(f)
        elif "중도주의" in f:
            f=f.replace(f,"중도")
            result_list6.append(f)             
        else:
            result_list6.append(f)
        
    p['스펙트럼']=result_list6    
    
    # 상징색 괄호만 없앰
    result_list7=[]
    
    for temp_index6 in index_listp:
        try:
            temp_data6=p.loc[temp_index6,:]
            g=temp_data6['상징색'].replace("[","(").replace("]",")").replace(" ","").replace("-",",").replace("\n\xa0\xa0\xa0\xa0",",").replace("\xa0\xa0\xa0\xa0",",")
            g=re.sub(r'\([^)]*\)', '', g).replace(')','').replace('(','')
            result_list7.append(g) 
        except:
            result_list7.append(g)
    
    p['상징색']=result_list7    

    result_list8 = []
    for temp_elem in list(p['창당']):
        try:
            if temp_elem.find('년') == -1: 
                result_list8.append('no result') 
                continue
            else: #'년'이 있으면
                temp_elem = temp_elem.replace(' ','').strip() 
                count = [i.start() for i in re.finditer('년',temp_elem)]
                temp_elem = temp_elem[max(0,count[len(count)-1]-5):count[len(count)-1]+8] 
              
                hangul_numb = re.compile('[^가-힣 0-9]+') 
                temp_elem = hangul_numb.sub('',temp_elem) 
               
                str1_, str2_, str3_ = '', '', ''   
                point1 = temp_elem.find('년')
                str1_ = temp_elem[:point1]
                if temp_elem.find('월') != -1:
                    point2 = temp_elem.find('월')  
                    str2_ = temp_elem[point1+1:point2] 
                    if temp_elem.find('일') != -1: 
                        point3 = temp_elem.find('일') 
                        str3_ = temp_elem[point2+1 : point3] 
                    else: 
                        pass
                else: 
                    pass
               
                if len(str2_) == 0: 
                    result_list8.append(str1_) 
                    continue
                elif len(str2_) == 1:
                    str2_ = '0' + str2_
                else: 
                    pass
               
                if len(str3_) == 0: 
                    result_list8.append(str1_ + str2_)
                    continue
                elif len(str3_) == 1:
                    str3_ = '0' + str3_
                else:
                    pass
               
                result_list8.append(str1_ + str2_ + str3_)
               
                       
                   
        except:
            result_list8.append('no result')
            
    p['창당'] = result_list8
    
   
    return p

print(list(party_info(df)['창당']))

# %%
    #마지막 콤마 뒤의 것만 가져오기 전에 마지막 콤마 뒤에 숫자만 남을 수 있도록 불필요한 문자 제거  
    result_list12 = []
    for qq in list(p['창당']):
        try:
            qq=qq.replace(":,중국국민당","").replace(", 민주사회당","").replace(":, 중국 국민당 ","").replace("/ 창당대회\xa0:","").replace(":, 좌파당.PDS","").replace(":, 중국국민당혁명위원회","")
            result_list12.append(qq) 
        except:
            result_list12.append(qq)    
    p['창당']=result_list12

# %%
    result_list11=[]
    for q in list(p['창당']):   
        try:
            if bool(re.match('.*:.*',q)) == True:   
                qfind=[i.start() for i in re.finditer(',',q)]
                result_list11.append(q[qfind[-1]+1:].strip())
            else:
                result_list11.append(q)
        except:
            pass
        
    p['창당']=result_list11

# %%
    # ㅠㅜ 콤마 뒤의 것만 가져오기
        
    result_list11=[]
    for q in list(p['창당']):   
        try:
            if bool(re.match('.*:.*',q)) == True:  
                qfind=[i.start() for i in re.finditer(',',q)]
                result_list11.append(q[qfind[-1]+1:].strip())
            else:
                result_list11.append(q)
        except:
            pass
        
    p['창당']=result_list11

# %%
    #콤마 뒤의 것만 가져온 다음에 이어붙이기!!!!!
    
    result_list8=[]
    for m in list(p['창당']):
        
        m=m.replace(' ','')
        point=m.find('년')
        point1=m.find('월')
        point2=m.find('일')
        
        #mm월 
        try:
            if len(m[point+1:point1]) == 1:
                m=m[:point+1]+'0'+m[point1-1:]
                result_list8.append(m)
            else:
                result_list8.append(m)
        except:
            pass
    p['창당']=result_list8
        
    result_list9=[]
    for mm in list(p['창당']):
        
        mm=mm.replace(' ','')
        point=mm.find('년')
        point1=mm.find('월')
        point2=mm.find('일')
        
        #mm월 
        try:
            if len(mm[point1+1:point2]) == 1:
                mm=mm[:point1+1]+'0'+mm[point2-1:]
                result_list9.append(mm)
            else:
                result_list9.append(mm)
        except:
            pass
    p['창당']=result_list9
    
    #년월일 없애기
    result_list10 = []
    for mmm in list(p['창당']):
        try:
            mmm=mmm.replace("년","").replace("월","").replace("-","").replace("일","").replace("\n","")
        except:
            result_list10.append(mmm)
    
    p['창당']=result_list10

# %%
a=[i.start() for i in re.finditer(',','9891216:,독사회주의통당,199024:,민주사회당,2005717')]
print(a)
print(len(a))
print(a[len(a)-1])
# Out:
# [8, 16, 24, 30]
# 4
# 30

# %%
pp=p.count()
print(pp.sort_values(ascending=False))
# Out:
# Unnamed: 0    541
# _id           541
# 이념            541
# 창당            464
# 스펙트럼          429
# 중앙당사          370
# 상징색           343
# 약칭            250
# 대표            212
# 해산            171
# 선행조직          151
# 청년조직          110
# 유럽 의회         104
# 후계정당          102
# 당수            100
# 유럽의회 교섭단체      79
# 국제조직           65
# 표어             64
# 활동기간           60
# 국회의원           54
# 활동지역           53
# 지도자            52
# 영어명            52
# 적대단체           50
# 지방의회           50
# 의회의석           50
# 분당 이전 정당       49
# 통합된 정당         48
# 하원의석           47
# 상원의석           46
# 원내대표           43
# 사무총장           43
# 본부             42
# 의장             42
# 총재             42
# 동맹단체           41
# 병력             41
# 창립자            40
# 유럽정당           40
# 상위단체           30
# 유래단체           28
# 지방 의회          28
# 선거연합           28
# 종교             24
# 주지사            23
# 참여한 전투         23
# 대통령            21
# 당원             20
# dtype: int64

# %%
#corp

import pandas as pd
corp_df=pd.read_excel('C:/Users/JalynneHEO/OneDrive - 주식회사 투디지트/바탕 화면/corp_info.xlsx', engine = 'openpyxl')
print(corp_df)
# Out:
#        Unnamed: 0     bizr_no  stock_code  corp_code       jurir_no  \
# 0               0  1208157558         NaN     100090  1101110359300
# 1               1  2198104458         NaN     100115  1101110404452
# 2               2  1028120878         NaN     100124  1101110101503
# 3               3  1348106102         NaN     100133  1301110009985
# 4               4  2148135261         NaN     100188  1101110374986
# ...           ...         ...         ...        ...            ...
# 83015       83015  5088141300         NaN    1513547  1101116523107
# 83016       83016  5068173878         NaN    1513556  1717140001760
# 83017       83017  8968801674         NaN    1513565  1101117640835
# 83018       83018  1858600436         NaN    1513574  1748110083701
# 83019       83019  1168159668    999980.0   99999999  1101111273111
#
#              corp_name                  corp_name_eng   stock_name ceo_nm  \
# 0           주식회사 LG스포츠                 LG SPORTS Ltd.        LG스포츠    이규홍
# ...

# %%
#df불러오기

import pandas as pd
import re
df=pd.read_excel(r'/Users/JalynneHEO/OneDrive - 주식회사 투디지트/바탕 화면/Jalynne_excercise3.xlsx', engine = 'openpyxl')
df1=pd.read_excel(r'/Users/JalynneHEO/OneDrive - 주식회사 투디지트/바탕 화면/Jalynne_excercise3.xlsx', engine = 'openpyxl')

# %%
print(corp_df)
# Out:
#        Unnamed: 0     bizr_no  stock_code  corp_code       jurir_no  \
# 0               0  1208157558         NaN     100090  1101110359300
# 1               1  2198104458         NaN     100115  1101110404452
# 2               2  1028120878         NaN     100124  1101110101503
# 3               3  1348106102         NaN     100133  1301110009985
# 4               4  2148135261         NaN     100188  1101110374986
# ...           ...         ...         ...        ...            ...
# 83015       83015  5088141300         NaN    1513547  1101116523107
# 83016       83016  5068173878         NaN    1513556  1717140001760
# 83017       83017  8968801674         NaN    1513565  1101117640835
# 83018       83018  1858600436         NaN    1513574  1748110083701
# 83019       83019  1168159668    999980.0   99999999  1101111273111
#
#              corp_name                  corp_name_eng   stock_name ceo_nm  \
# 0           주식회사 LG스포츠                 LG SPORTS Ltd.        LG스포츠    이규홍
# ...

# %%
#9 기업명이 포함된 df 중에서 유의미한 자료만 추출하기

import re
import numpy as np
import pandas as pd
from tqdm import tqdm

def corp(df,corp_df):
    
    #df=50000, corp_df=기업명

    i=corp_df.dropna(subset=['stock_code'])#i는 stock_code가 있는 데이터프레임
    df=df.dropna(axis=1,how='all')
    name_list=list(i['stock_name']) #데이터프레임 i의 기업 이름
    
    final=[]
    temp_list = []
    

    for b in tqdm(list(df.index)):
        values=[] 
        temp_data1=df.loc[b,:]    
        
        
        #key안에 있는 모든 value들을 append 하기
          
        for key in temp_data1.keys():
            if str(temp_data1[key]) != 'nan':
                values.append(temp_data1[key])

        flag = 0
        for c in name_list: #name_list는 stock_name
            for d in values: #셀 전부다
                try: 
                    d=d.replace(' ','')      
                    if c in d:
                        final.append(b)

                        temp_list.append(c) #기업이름
                        temp_list.append(d) #공백없앤 셀
                        temp_list.append(b) #index number
                        flag = 1
                        break
                    else:
                        pass
                except:
                    pass
            if flag == 1:
                break
            else:
                pass      
    df=df.loc[final, :]   # df.loc[final, :]=기업이름이 있는 df row=13677개
      
    
    #불필요한 정보 없애기 (도시 이름+ a )    
    city=['강원도','남원','남양주','삼일','CS','대교','덕성','한독','서흥','동서','서연','백산','남성','대국','동양','동아','국보','태양','대덕구','수성구','진도군','싸이월드','연예대상','연기대상','디오','레이','서산시','유신']
433, 48439, 48440, 48446, 48453, 48458, 48461, 48463, 48464, 48482, 48483, 48488, 48490, 48491, 48492, 48495, 48496, 48500, 48505, 48516, 48518, 48522, 48545, 48552, 48563, 48568, 48569, 48581, 48600, 48611, 48620, 48621, 48627, 48633, 48647, 48654, 48680, 48682, 48690, 48693, 48703, 48729, 48733, 48750, 48770, 48784, 48797, 48818, 48824, 48825, 48839, 48842, 48844, 48850, 48859, 48862, 48877, 48884, 48898, 48910, 48922, 48926, 48933, 48935, 48946, 48949, 48964, 48980, 48983, 48986, 48988, 48993, 48997, 48998, 49000, 49005, 49012, 49015, 49016, 49018, 49034, 49038, 49055, 49068, 49072, 49110, 49119, 49121, 49129, 49134, 49137, 49148, 49150, 49154, 49157, 49161, 49168, 49169, 49170, 49179, 49181, 49188, 49207, 49214, 49215, 49228, 49245, 49251, 49254, 49257, 49263, 49265, 49269, 49276, 49277, 49302, 49313, 49331, 49335, 49336, 49348, 49352, 49368, 49369, 49370, 49376, 49378, 49387, 49390, 49394, 49405, 49409, 49411, 49431, 49432, 49433, 49442, 49445, 49460, 49461, 49468, 49469, 49470, 49471, 49475, 49488, 49496, 49500, 49511, 49523, 49524, 49549, 49559, 49560, 49564, 49577, 49580, 49587, 49589, 49614, 49622, 49628, 49637, 49640, 49646, 49650, 49652, 49670, 49673, 49678, 49694, 49703, 49707, 49725, 49734, 49738, 49741, 49745, 49755, 49761, 49763, 49781, 49782, 49785, 49787, 49805, 49807, 49813, 49815, 49816, 49822, 49830, 49838, 49844, 49848, 49876, 49879, 49886, 49905, 49917, 49918, 49947, 49966, 49967, 49982, 49984, 49985, 49992, 49993, 49999])
    #df=df.query('모기업.notnull() or 상장일.notnull() or `사업 내용`.notnull() or `영업 이익`.notnull() or `자산 총액`.notnull() or 창립자.notnull() or 자본금.notnull() or `본사 소재지`.notnull() or 순이익.notnull() or 자본금.notnull() or 매출액.notnull() or 제조사.notnull() or 자회사.notnull() or `주요 주주`.notnull() or `주요 제조사`.notnull()')
    
    
    # 기업명이랑 관련된 column 찾아내기      
    key_list=list(df.keys())
    count_dic={}
    for key in key_list:
        count_dic[key] = 0
    
    
    #기업 이름이 몇 번 나왔는지 - 딕셔너리
    for key in tqdm(list(count_dic.keys())):    
        for name in name_list:         
            target_list = list(df[key])
            for temp_elem in target_list:
                try:
                    if name in temp_elem:
                        count_dic[key] += 1 
                    else:
                        pass
                except:
                    pass
                   
    print(count_dic)
    
    return df
    
print(corp(df,corp_df))
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 1575/1575 [7:17:50<00:00, 16.68s/it]
# ...

# %%
important_data = {'Unnamed: 0': 0, '_id': 1756, '건학이념': 2, '교색': 3, '교직원 수': 0, '국가': 13, '규모': 1, '대학원생 수': 0, '부총장': 0, '상징물': 3, '설립': 1, '설립자': 7, '웹사이트': 561, '종교': 40, '종류': 4, '총장': 6, '표어': 6, '학교법인': 54, '학부생 수': 0, '감독': 33, '리그': 1, '별칭': 5, '경력': 102, '국적': 0, '배우자': 95, '본관': 26, '임기': 1, '자녀': 79, '전임': 38, '정
 명명법': 1, '밝은 별 목록': 0, '소천성표': 0, '스미소니언 천문대 항성목록': 0, '플램스티드 명명법': 1, '헨리 드레이퍼 목록': 0, '히파르코스 목록': 0, '캐릭터 원안': 0, '3': 0, '이름 설정': 0, '터치패드': 0, '엔딩 수': 0, '감도 범위': 0, '기록 매체': 0, '동영상 촬영': 0, '렌즈 마운트': 0, '뷰파인더': 0, '뷰파인더 시야율': 0, '셔터': 0, '셔터 속도 범위': 0, '연사 속도': 0, '이미지 센서 종류': 0, '이미지 센서 크기': 0, '초점 방식': 1, '최대 해상도': 0, '포커스 영역': 0, '개발 년도': 0, '시진': 0}

# %%
sort_orders = sorted(important_data.items(), key=lambda x: x[1], reverse=True)

# %%
for i in sort_orders:
	print(i[0], i[1])
# Out:
# _id 1756
# 주요 주주 626
# 웹사이트 561
# 레이블 404
# 모기업 388
# 자회사 311
# 방송 채널 241
# 소속사 205
# 창립 189
# 위치 187
# 본사 소재지 161
# 배급사 159
# 제작사 157
# 소속 143
# 경력 102
# IPTV 채널 96
# 배우자 95
# 제작자 95
# 전신 91
# 기획 86
# 해체 85
# 출생지 83
# 학력 82
# 제조사 81
# 자녀 79
# 추가 채널 77
# 현 소속팀 74
# 사용처 72
# 외부 링크 71
# 방송사 71
# 핵심 인물 69
# 시호 65
# 활동 기간 64
# 부친 63
# 최대 진도 59
# 소재지 58
# 모친 57
# 소속팀 57
# 제작 56
# 수상 55
# 학교법인 54
# 부모 53
# 후신 52
# 계열사 50
# 사망지 47
# 제품 43
# 종교 40
# 교장 39
# 전임 38
# 가문 38
# 소유주 38
# 프로듀서 38
# 라이선스 37
# 본명 36
# 관련 활동 36
# 출연자 36
# 경기장 35
# 각본 35
# 출생 34
# 시간대 34
# 연출 34
# 출판사 34
# 감독 33
# 주소 32
# 커널 32
# 창립자 31
# 네트워크 30
# 분할 29
# 거점 항공사 29
# 출연 29
# 데뷔작(곡) 27
# 운영기관 27
# 본관 26
# 휘 26
# 기타 이력 26
# 소속 그룹 26
# 역사 26
# 시공사 26
# 본사 25
# IATA 25
# 리그 우승 24
# 약칭 23
# 후임 23
# 장르 23
# 주요 사용자 23
# 개발자 23
# 총리 22
# 교감 22
# 시장 정보 22
# 건축가/건축회사 22
# 주요 인물 21
# 보유자 21
# 기타 친인척 21
# 시장 21
# 편집 21
# 언어 계통 20
# 홈 경기장 20
# 이전 상호 20
# 개발사 19
# 경기 19
# 건설 18
# 건설사 18
# 교훈 17
# 발사 장소 17
# 형제 17
# 소유자 17
# 수도 16
# ...

# %%
#9 기업명이 포함된 df 중에서 유의미한 자료만 추출하기

import re
import numpy as np
import pandas as pd
from tqdm import tqdm

def corp(df,corp_df):
    
    #df=50000, corp_df=기업명

    i=corp_df.dropna(subset=['stock_code'])#i는 stock_code가 있는 데이터프레임
    name_list=list(i['stock_name']) #데이터프레임 i의 기업 이름
    
    final=[]
    temp_list = []
    

    for b in tqdm(list(df.index)):
        values=[] 
        temp_data1=df.loc[b,:]    
        
        
        #key안에 있는 모든 value들을 append 하기
          
        for key in temp_data1.keys():
            if str(temp_data1[key]) != 'nan':
                values.append(temp_data1[key])

        flag = 0
        for c in name_list: #name_list는 stock_name
            for d in values: #셀 전부다
                try: 
                    d=d.replace(' ','')      
                    if c in d:
                        final.append(b)

                        temp_list.append(c) #기업이름
                        temp_list.append(d) #공백없앤 셀
                        temp_list.append(b) #index number
                        flag = 1
                        break
                    else:
                        pass
                except:
                    pass
            if flag == 1:
                break
            else:
                pass      
    df=df.loc[final, :]   # df.loc[final, :]=기업이름이 있는 df row=13677개
      
    
    #불필요한 정보 없애기 (도시 이름+ a )    
    city=['강원도','남원','남양주','삼일','CS','대교','덕성','한독','서흥','동서','서연','백산','남성','대국','동양','동아','국보','태양','대덕구','수성구','진도군','싸이월드','연예대상','연기대상','디오','레이','서산시','유신']
    city_drop=[] #drop할 index 
    
    for bb in tqdm(list(df.index)):
        values1=[]
        temp_data11=df.loc[bb,:]
        
        for key in temp_data11.keys():
            if str(temp_data11[key]) != 'nan':
                values1.append(temp_data11[key])
        
        flag = 0
        for e in city:
            for f in values1:
                try: 
                    f=f.replace(' ','')                      
                    if e in f:
                        city_drop.append(bb)
                        flag = 1
                        break                        
                    else:
                        pass
                except:
                    pass
            if flag == 1:
                break
            else:
                pass      
    
    #print(city_drop)
    df=df.drop(index=[1, 3, 4, 6, 11, 19, 21, 22, 26, 28, 31, 34, 35, 36, 37, 39, 51, 54, 57, 58, 60, 63, 65, 67, 73, 74, 75, 76, 78, 80, 82, 83, 87, 88, 91, 98, 104, 110, 112, 115, 118, 123, 126, 129, 132, 133, 134, 143, 144, 152, 158, 166, 170, 179, 181, 182, 187, 191, 199, 201, 208, 210, 215, 219, 231, 240, 245, 246, 247, 251, 261, 262, 267, 275, 278, 281, 290, 296, 302, 303, 304, 314, 319, 327, 334, 335, 336, 346, 353, 363, 364, 367, 369, 372, 374, 375, 377, 385, 386, 394, 396, 397, 400, 403, 405, 408, 409, 411, 414, 422, 423, 424, 425, 428, 430, 431, 437, 438, 440, 452, 458, 464, 465, 469, 482, 493, 494, 495, 513, 514, 523, 530, 538, 544, 558, 568, 570, 571, 574, 575, 590, 591, 593, 594, 607, 608, 621, 623, 628, 636, 638, 639, 641, 643, 644, 649, 651, 663, 664, 666, 669, 679, 680, 684, 688, 692, 698, 705, 711, 722, 729, 735, 736, 737, 738, 741, 743, 744, 748, 753, 757, 764, 769, 770, 794, 796, 827, 828, 830, 832, 845, 847, 859, 861, 865, 868, 880, 886, 890, 891, 893, 894, 899, 905, 909, 913, 914, 917, 918, 923, 924, 927, 954, 956, 957, 969, 970, 979, 997, 998, 1005, 1011, 1015, 1020, 1029, 1030, 1031, 1032, 1052, 1063, 1067, 1068, 1085, 1093, 1103, 1104, 1105, 1120, 1130, 1137, 1147, 1154, 1159, 1168, 1170, 1176, 1188, 1195, 1196, 1198, 1220, 1221, 1223, 1225, 1236, 1237, 1249, 1253, 1256, 1258, 1259, 1267, 1278, 1294, 1295, 1301, 1308, 1321, 1330, 1334, 1354, 1366, 1369,
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████| 13677/13677 [01:35<00:00, 143.40it/s]
# ...

# %%
#9 기업명이 포함된 df 중에서 유의미한 자료만 추출하기

import re
import numpy as np
import pandas as pd
from tqdm import tqdm

def corp(df,corp_df):
    
    #df=50000, corp_df=기업명

    i=corp_df.dropna(subset=['stock_code'])#i는 stock_code가 있는 데이터프레임
    name_list=list(i['stock_name']) #데이터프레임 i의 기업 이름
    
    final=[]
    temp_list = []
    

    for b in tqdm(list(df.index)):
        values=[] 
        temp_data1=df.loc[b,:]    
        
        
        #key안에 있는 모든 value들을 append 하기
          
        for key in temp_data1.keys():
            if str(temp_data1[key]) != 'nan':
                values.append(temp_data1[key])

        flag = 0
        for c in name_list: #name_list는 stock_name
            for d in values: #셀 전부다
                try: 
                    d=d.replace(' ','')      
                    if c in d:
                        final.append(b)

                        temp_list.append(c) #기업이름
                        temp_list.append(d) #공백없앤 셀
                        temp_list.append(b) #index number
                        flag = 1
                        break
                    else:
                        pass
                except:
                    pass
            if flag == 1:
                break
            else:
                pass      
    df=df.loc[final, :]   # df.loc[final, :]=기업이름이 있는 df row=13677개
      
    
    #불필요한 정보 없애기 (도시 이름+ a )    
    city=['강원도','남원','남양주','삼일','CS','대교','덕성','한독','서흥','동서','서연','백산','남성','대국','동양','동아','국보','태양','대덕구','수성구','진도군','싸이월드','연예대상','연기대상','디오','레이','서산시','유신']
    city_drop=[] #drop할 index 
    
    for bb in tqdm(list(df.index)):
        values1=[]
        temp_data11=df.loc[bb,:]
        
        for key in temp_data11.keys():
            if str(temp_data11[key]) != 'nan':
                values1.append(temp_data11[key])
        
        flag = 0
        for e in city:
            for f in values1:
                try: 
                    f=f.replace(' ','')                      
                    if e in f:
                        city_drop.append(bb)
                        flag = 1
                        break                        
                    else:
                        pass
                except:
                    pass
            if flag == 1:
                break
            else:
                pass      
    
    #print(city_drop)
    df=df.drop(index=[1, 3, 4, 6, 11, 19, 21, 22, 26, 28, 31, 34, 35, 36, 37, 39, 51, 54, 57, 58, 60, 63, 65, 67, 73, 74, 75, 76, 78, 80, 82, 83, 87, 88, 91, 98, 104, 110, 112, 115, 118, 123, 126, 129, 132, 133, 134, 143, 144, 152, 158, 166, 170, 179, 181, 182, 187, 191, 199, 201, 208, 210, 215, 219, 231, 240, 245, 246, 247, 251, 261, 262, 267, 275, 278, 281, 290, 296, 302, 303, 304, 314, 319, 327, 334, 335, 336, 346, 353, 363, 364, 367, 369, 372, 374, 375, 377, 385, 386, 394, 396, 397, 400, 403, 405, 408, 409, 411, 414, 422, 423, 424, 425, 428, 430, 431, 437, 438, 440, 452, 458, 464, 465, 469, 482, 493, 494, 495, 513, 514, 523, 530, 538, 544, 558, 568, 570, 571, 574, 575, 590, 591, 593, 594, 607, 608, 621, 623, 628, 636, 638, 639, 641, 643, 644, 649, 651, 663, 664, 666, 669, 679, 680, 684, 688, 692, 698, 705, 711, 722, 729, 735, 736, 737, 738, 741, 743, 744, 748, 753, 757, 764, 769, 770, 794, 796, 827, 828, 830, 832, 845, 847, 859, 861, 865, 868, 880, 886, 890, 891, 893, 894, 899, 905, 909, 913, 914, 917, 918, 923, 924, 927, 954, 956, 957, 969, 970, 979, 997, 998, 1005, 1011, 1015, 1020, 1029, 1030, 1031, 1032, 1052, 1063, 1067, 1068, 1085, 1093, 1103, 1104, 1105, 1120, 1130, 1137, 1147, 1154,
            core = re.sub(r'\([^)]*\)', '', core).replace(')', '').replace('(', '')
            result.append(core)
            
        except:
            result.append('no result')
    
    df['핵심 인물']=result
    
    
    result1=[]
    for founder in list(df['창립자']):
        try:
            founder = founder.replace("[", "(").replace("]", ")").replace("{", "(").replace("}", ")")
            founder = re.sub(r'\([^)]*\)', '', founder).replace(')', '').replace('(', '')
            result1.append(founder)
        
        except:
            result1.append('no result')
            
    df['창립자']=result1
    
    result2=[]
    for product in list(df['제품']):
        try:
            product = product.replace("[", "(").replace("]", ")").replace("{", "(").replace("}", ")").replace("\n",",").replace("/",",")
            product = re.sub(r'\([^)]*\)', '', product).replace(')', '').replace('(', '')
            result2.append(product)
            
        except:
            result2.append('no result')
            
    df['제품']=result2           
    df=df.dropna(axis=1, how='all')
    
#     print(list(df['핵심 인물']))
#     print('----------------------------------------------------------------------------------------------------------')
#     print(list(df['제품']))
#     print('----------------------------------------------------------------------------------------------------------')    
#     print(list(df['창립자']))
#     print(list(df.index))
    
    return df
    

     
print(corp(df,corp_df))
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████| 13677/13677 [01:36<00:00, 141.34it/s]
# ...

# %%
#제품

import numpy as np
import pandas as pd

#df=df1 같은거임

df1=df1.query('개발사.notnull() or 개발자.notnull() or 출시일.notnull() or 발표일.notnull()')
df1=df1.dropna(axis=1, how='all')

# def product(df1,corp_df):
    
#     result=[]
#     for id in list(df1['_id']):
#         try:
#             id = id.replace("\n"," ")
#             result.append(id)

#         except:
#             result.append('no result')
#     df1['_id']=result               

#     result_list = []
#     for id in list(df1['_id']):
#         try:
#             id = re.sub(r'[^ ㄱ-ㅣ가-힣A-Za-z]', '', id)
#             result_list.append(id)
#         except:
#             result_list.append(id)
            
#     df1['_id']=result_list
    
#     print(list(df1['_id']))

#     return df1

print(list(df1['_id']))
# Out:
# ['빌딩 한화시티 Hanwha  City', '도쿄 스카이 트리TOKYO SKYTREE ', '호 전차', '파스칼', '서초 삼성타운 Samsung Town Headquarters', '부산국제금융센터 Busan International Finance Center', '안드로이드 프로요', 'iOS iPhone OS', 'C 프로그래밍 언어', '인스타그램', 'D', 'PHP', 'M 패튼', 'K 전차', '스칼라Scala', '루비Ruby', '자바Java', '자바스크립트JavaScript', 'SNOBOL', '에펠', '시뮬라', '클랭Clang', '스위프트Swift', 'CPython', '사이썬Cython', '어셈블리어', 'OpenJDK', 'HHVM', 'OCaml', 'GNU 일반 공중 사용 허가서', 'V', '러스트Rust', '커피스크립트CoffeeScript', '파워셸PowerShell', 'Julia', 'sed', '비주얼 베이직', '아파치 라이선스', '포트란', '리스프', '클로저', 'AWK', 'GNU Compiler for Java', '라쿠', '루아', 'F', '그루비Groovy', 'Haskell', '옥시즌', '리눅스Linux', 'C', 'IronPython', '팰컨', '마이크로소프트 윈도우Microsoft Windows', '발라', 'B', '파이썬Python', '얼랭Erlang', 'FreeBSD', '스몰토크', 'ALGOL ', '젠드 프레임워크', '오브젝티브CObjectiveC', '닷넷 프레임워크NET Framework', '젠드 엔진', '모노Mono', 'C 셸', 'C', 'macOS', '코틀린', 'GNU Compiler Collection', 'Go', '오즈', 'V', '웹킷', '베이직', 'LLVM', '오픈 왓콤 CC', '콘셸KornShell', '윈도우 ', '페도라Fedora', '루비', '멀틱스', '확장 응용 프로그램 마크업 언어Extensibl
# ...

# %%
    # 기업명이랑 관련된 column 찾아내기      
    key_list=list(df.keys())
    count_dic={}
    for key in key_list:
        count_dic[key] = 0
    
    
    #기업 이름이 몇 번 나왔는지 - 딕셔너리
    for key in tqdm(list(count_dic.keys())):    
        for name in name_list:         
            target_list = list(df[key])
            for temp_elem in target_list:
                try:
                    if name in temp_elem:
                        count_dic[key] += 1 
                    else:
                        pass
                except:
                    pass
                   
    print(count_dic)

# %%
symbol_dir = 'C:/Users/JalynneHEO/OneDrive - 주식회사 투디지트/바탕 화면/nasdaq_screener_210406.xlsx'
synonym_dir = 'C:/Users/JalynneHEO/OneDrive - 주식회사 투디지트/바탕 화면/Yahoo_US_Stock_list_synonym_2021_0405_v0.5.csv'

# %%
import pandas as pd
symbol_data = pd.read_excel(symbol_dir, engine = 'openpyxl', dtype = 'object') # 대형주 224개
symbol_list = symbol_data['Symbol'] #대형주 파일에서 'symbol' 칼럼만 가져오기 (종목명)
synonym_data = pd.read_csv(synonym_dir, dtype = 'object', sep = ',', encoding = 'latin')

# %%
from tqdm import tqdm

# %%
index_list = []              
for i in tqdm(symbol_list): 
    for j in range(len(synonym_data)): # len = 행 전체
        if i == synonym_data.loc[j, :]['symbol_yahoo']: # 행 중에서 'symbol_yahoo'에 해당하는 것
            index_list.append(j)
            break
        else:
            pass
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 224/224 [01:39<00:00,  2.26it/s]

# %%
for _ in symbol_list: 
    if _ not in list(synonym_data['symbol_yahoo']):
        print(_)
# Out:
# INCY

# %%
synonym_data = synonym_data.loc[index_list, :] 
print(synonym_data)
# Out:
#      symbol_yahoo                                            name  \
# 17           AAPL                          Apple Inc Common Stock
# 4421         MSFT              Microsoft Corporation Common Stock
# 417          AMZN                     Amazon.com Inc Common Stock
# 2961         GOOG              Alphabet Inc Class C Capital Stock
# 2962        GOOGL               Alphabet Inc Class A Common Stock
# ...           ...                                             ...
# 1047         BRKR                 Bruker Corporation Common Stock
# 2886         GLPI  Gaming and Leisure Properties Inc Common Stock
# 4160         MCFE               McAfee Corp. Class A Common Stock
# 4358         MORN                    Morningstar Inc Common Stock
# 5345         PRAH            PRA Health Sciences Inc Common Stock
#
#                              Unnamed: 2                     Unnamed: 3  \
# 17                            Apple Inc                          Apple
# ...

# %%
synonym_data.loc[20000,'symbol_yahoo'] = 'INCY'

# %%
print(len(synonym_data))
# Out:
# 224

# %%
import time
import datetime
import requests
import json

# %%
import torch
import pandas as pd
from tqdm import tqdm
import sentencepiece as spm
from model_SGNS import SGNS
import urllib.request
import zipfile
from lxml import etree
import re
import pandas as pd
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/GaoleMeng/RNN-and-FFNN-textClassification/master/ted_en-20160408.xml", filename="ted_en-20160408.txt")
# Out:
# ('ted_en-20160408.txt', <http.client.HTTPMessage at 0x1ba33526b00>)

# %%
targetXML=open('ted_en-20160408.txt', 'r', encoding='UTF8')
target_text = etree.parse(targetXML)

# xml 파일로부터 <content>와 </content> 사이의 내용만 가져온다.
parse_text = '\n'.join(target_text.xpath('//content/text()'))

# 정규 표현식의 sub 모듈을 통해 content 중간에 등장하는 (Audio), (Laughter) 등의 배경음 부분을 제거.
# 해당 코드는 괄호로 구성된 내용을 제거.
content_text = re.sub(r'\([^)]*\)', '', parse_text)

# 입력 코퍼스에 대해서 NLTK를 이용하여 문장 토큰화를 수행.
sent_text = sent_tokenize(content_text)

# 각 문장에 대해서 구두점을 제거하고, 대문자를 소문자로 변환.
normalized_text = []
for string in sent_text:
     tokens = re.sub(r"[^a-z0-9]+", " ", string.lower())
     normalized_text.append(tokens)

# 각 문장에 대해서 NLTK를 이용하여 단어 토큰화를 수행.
result = [word_tokenize(sentence) for sentence in normalized_text]

# %%
import sentencepiece as spm
import pandas as pd
import urllib.request
import csv
import torch
import pandas as pd
from tqdm import tqdm
import sentencepiece as spm
from model_SGNS import SGNS
import sentencepiece
import pandas as pd
import csv

# %%
#%%
with open('ted_eng.txt') as data:
   lines = data.readlines()

# %%
result = [word_tokenize(sentence) for sentence in normalized_text]
#print(result)

# %%
result = [sp.EncodeAsIds(i) for i in lines]

# %%
sentencepiece.SentencePieceTrainer.Train('--input=ted_en-20160408.txt '
                               '--model_prefix=ted '
                               '--vocab_size=3000 '
                               '--model_type=bpe '
                               '--max_sentence_length=1000')

# %%
sp = spm.SentencePieceProcessor()
vocab_file = './ted.model'
#load the vocab file
sp.Load(vocab_file) #Load
# Out:
# True

# %%
model = SGNS(sp.GetPieceSize(), 50)
criterion = torch.nn.CrossEntropyLoss

optimizer = torch.optim.Adam(model.parameters(), lr=0.01) 
for sentence in tqdm(result): 
    for word_num in range(len(sentence)): 
        # for words in window size 2, label 1 and learn
        for _ in [-2,-1,1,2]:
            if word_num + _ < 0: 
                pass 
            elif word_num + _ >= len(sentence): 
                pass
            else:
                #input two number
                output = model.forward(sentence[word_num],sentence[word_num +_]) # number_1, number_2
                
                
                if output is None:
                    pass
                else:
                    output = output.unsqueeze(0)
                    loss = criterion(output, torch.LongTensor([1])) 
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

        # get random 5 words for each center word
        random_words = torch.randint(0, sp.GetPieceSize(), (5,)) 
        for _ in range(5): 
            # if random word is in neighbor, pass 
            # print(random_words[_].item())
            if random_words[_].item() in sentence[max(0,word_num -2):word_num + 2]: #max를 써준 이유는 음수가 들어가면 안돼서
                pass
            #랜덤 words가 주변단어일 경우 pass
            else: 
                # output = model.forward(sentence[word_num],sentence[word_num + _]) 내가 잘못 적은 답
                output = model.forward(sentence[word_num],random_words[_].item())
                #위에서 output 이랑 여기서 output 이랑 왜 다른건 네거티브 샘플링이니까 주변단어랑 관계없는 단어들까지 전부다 학습
                
                if output is None: 
                    pass
                else:
                    output = output.unsqueeze(0)
                    loss = criterion(output, torch.LongTensor([0])) # 관련없는 단어는 라벨을 0으로 설정
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

torch.save(model.state_dict(), 'C:/Users/JalynneHEO/OneDrive - 주식회사 투디지트/바탕 화면/ted_eng')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 273424/273424 [7:36:07<00:00,  9.99it/s]

# %%
model.load_state_dict(torch.load('C:/Users/JalynneHEO/OneDrive - 주식회사 투디지트/바탕 화면/ted_eng'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6bf5a761beab> in <module>
# ----> 1 model.load_state_dict(torch.load('C:/Users/JalynneHEO/OneDrive - 주식회사 투디지트/바탕 화면/ted_eng'))
#
# NameError: name 'model' is not defined

# %%
import sentencepiece as spm
import sentencepiece
import pandas as pd
import csv
import torch

# %%
import torch
import pandas as pd
from tqdm import tqdm
import sentencepiece as spm
from torch import nn

# %%
with open('ted_eng.txt') as data:
   lines = data.readlines()

# %%
#%%
import urllib.request
import zipfile
from lxml import etree
import re
import pandas as pd
from nltk.tokenize import word_tokenize, sent_tokenize
#%%
urllib.request.urlretrieve("https://raw.githubusercontent.com/GaoleMeng/RNN-and-FFNN-textClassification/master/ted_en-20160408.xml", filename="ted_en-20160408.txt")
# Out:
# ('ted_en-20160408.txt', <http.client.HTTPMessage at 0x21470ef9518>)

# %%
targetXML=open('ted_en-20160408.txt', 'r', encoding='UTF8')
target_text = etree.parse(targetXML)

# xml 파일로부터 <content>와 </content> 사이의 내용만 가져온다.
parse_text = '\n'.join(target_text.xpath('//content/text()'))

# 정규 표현식의 sub 모듈을 통해 content 중간에 등장하는 (Audio), (Laughter) 등의 배경음 부분을 제거.
# 해당 코드는 괄호로 구성된 내용을 제거.
content_text = re.sub(r'\([^)]*\)', '', parse_text)

# 입력 코퍼스에 대해서 NLTK를 이용하여 문장 토큰화를 수행.
sent_text = sent_tokenize(content_text)

# 각 문장에 대해서 구두점을 제거하고, 대문자를 소문자로 변환.
normalized_text = []
for string in sent_text:
     tokens = re.sub(r"[^a-z0-9]+", " ", string.lower())
     normalized_text.append(tokens)

# 각 문장에 대해서 NLTK를 이용하여 단어 토큰화를 수행.
result = [word_tokenize(sentence) for sentence in normalized_text]

# %%
result = [word_tokenize(sentence) for sentence in normalized_text]
#print(result)
#%%
result = [sp.EncodeAsIds(i) for i in lines]

# %%
class SGNS(torch.nn.Module):
    def __init__(self, D_dim, W_dim): 
        super(SGNS, self).__init__()
        self.dict_len = D_dim
        self.linear1 = torch.nn.Linear(D_dim, W_dim)
        self.linear2 = torch.nn.Linear(D_dim, W_dim)
        
    def forward(self, number_1, number_2): 
        try:
            temp_tensor = torch.Tensor([0]*self.dict_len)
            temp_tensor[number_1] = 1
            
            projection = self.linear1(temp_tensor) #.squeeze(0) 
            
            temp_tensor2 = torch.Tensor([0]*self.dict_len)
            temp_tensor2[number_2] = 1 
            
            projection2 = self.linear2(temp_tensor2)
            output = torch.dot(projection.squeeze(0), projection2.squeeze(0))
            output = torch.sigmoid(output)
            output = output.unsqueeze(0)
            
#             print(torch.Tensor([1 - output[0].item()]))
#             print(output)
            output = torch.cat((torch.Tensor([1 - output[0].item()]), output), dim=-1)
#             print(output)
            
            
        except Exception as e:
            print(e)
            
            return None

# %%
#train blank_SGNS.py 

model = SGNS(sp.GetPieceSize(), 50)
criterion = torch.nn.CrossEntropyLoss

optimizer = torch.optim.Adam(model.parameters(), lr=0.01) 
for sentence in tqdm(result): 
    for word_num in range(len(sentence)): 
       
        for _ in [-2,-1,1,2]:
            if word_num + _ < 0: 
                pass 
            elif word_num + _ >= len(sentence): 
                pass
            else:
                #input two number
                output = model.forward(sentence[word_num],sentence[word_num +_])
                if output is None:
                    pass
                else:
                    output = output.unsqueeze(0)
                    loss = criterion(output, torch.LongTensor([1])) 
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

        random_words = torch.randint(0, sp.GetPieceSize(), (5,)) 
        for _ in range(5): 
            if random_words[_].item() in sentence[max(0,word_num -2):word_num + 2]: 
                pass
            else: 
                output = model.forward(sentence[word_num],random_words[_].item())
                
                if output is None: 
                    pass
                else:
                    output = output.unsqueeze(0)
                    loss = criterion(output, torch.LongTensor([0])) 
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

torch.save(model.state_dict(), 'C:/Users/JalynneHEO/OneDrive - 주식회사 투디지트/바탕 화면/ted_re')

# %%
a=['a','b','c']
print(len(a))
# Out:
# 3

# %%
list = ['a', 'b', 'c']
print([-1] * (4-len(batch)) + batch for batch in list)
# Out:
# <generator object <genexpr> at 0x000001D1E01116D0>

# %%
print([-11]+[2,3,4])
# Out:
# [-11, 2, 3, 4]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.datasets import imdb
import torch
import pandas as pd
from tqdm import tqdm
import sentencepiece as spm
from random import randint
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from lxml import etree
from nltk.tokenize import word_tokenize, sent_tokenize
import re
import nltk
from tqdm import tqdm
import itertools
from collections import Counter
import random
import numpy as np
import torch
import torch.nn as nn
import torch.autograd as autograd
import torch.optim as optim
import torch.nn.functional as F

# %%
data = pd.read_csv('C:/Users/JalynneHEO/IMDB_Dataset.csv', engine = 'python-fwf', dtype = object)

# %%
print(data['review,sentiment'])
# Out:
# 0        "One of the other reviewers has mentioned that...
# 1        "A wonderful little production. <br /><br />Th...
# 2        "I thought this was a wonderful way to spend t...
# 3        "Basically there's a family where a little boy...
# 4        "Petter Mattei's ""Love in the Time of Money""...
#                                ...
# 49995    "I thought this movie did a down right good jo...
# 49996    "Bad plot, bad dialogue, bad acting, idiotic d...
# 49997    "I am a Catholic taught in parochial elementar...
# 49998    "I'm going to have to disagree with the previo...
# 49999    "No one expects the Star Trek movies to be hig...
# Name: review,sentiment, Length: 50000, dtype: object

# %%
print(bool(re.match('.*→.*','유교 개신교')))
# Out:
# False

# %%
point = [i.start() for i in re.finditer('→','유교 → 불교 → 개신교')]
print(point[-1])
# Out:
# 8

# %%
# XXX
a = '유교(성리학)'.replace(r"\(.*\)","")
print(a)
# Out:
# 유교(성리학)

# %%
# OOO
remove_text ='유교(성리학)'
print(re.sub(r'\([^)]*\)', '', remove_text))
# Out:
# 유교
